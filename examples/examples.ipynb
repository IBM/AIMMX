# %% [markdown]
# ## Example usage for AIMMX
#
# This notebook demonstrates how to use AIMMX for both individual and many repositories.

# %% [markdown]
# ## Obtain GitHub API Key
#
# The GitHub API key is a private key that AIMMX uses to request data from GitHub about particular repositories.
#
# The API key can be obtained by the following steps:
#
# 1. On [GitHub](https://github.com/), click your profile picture in the top-right
#
# 2. [Settings > Developer Settings > Personal access tokens > "Generate new token"](https://github.com/settings/tokens)
#
# 3. Keep track of the key that is generated for use later
#
# As a note, there is a rate limitation with the GitHub API so be careful when analzying very large numbers of repositories.

# %%
GITHUB_API_KEY = "***PASTE YOUR API KEY HERE***"

# %%
from aimmx import AIMMX
import pprint

aimmx = AIMMX(GITHUB_API_KEY)
metadata = aimmx.repo_parse("https://github.com/vadimkantorov/cvpr2014")
pprint.pprint(metadata, indent=4)
# Out:
# Extracting AI model metadata from:  vadimkantorov/fastvideofeat
# {   'authors': [   {   'email': 'vadimkantorov@gmail.com',
#                        'github_id': 'vadimkantorov',
#                        'name': 'Vadim Kantorov'}],
#     'definition': {   'code': [   {   'description': 'Efficient feature '
#                                                      'extraction, aggregation '
#                                                      'and classification for '
#                                                      'action recognition (CVPR '
#                                                      '2014)',
#                                       'frameworks': ['scikit-learn'],
#                                       'language': 'TeX',
#                                       'license': 'MIT License',
#                                       'name': 'cvpr2014',
#                                       'owner': 'vadimkantorov',
#                                       'pushed_at': '2015-12-25 19:19:46+00:00',
#                                       'repo_type': 'github',
#                                       'stars': 110,
#                                       'type': 'repo',
#                                       'url': 'https://github.com/vadimkantorov/cvpr2014'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/blob/master/LICENSE'}},
#                                       'filetype': 'file',
#                                       'name': 'LICENSE',
#                                       'sha': '0729c551b50fd90a4808d1f07c3c53102b128068',
#                                       'size': 1086,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/bin'}},
#                                       'filetype': 'dir',
#                                       'name': 'bin',
#                                       'num_files': 1,
#                                       'sha': 'f52cf0b88ad0dba05a036ab7376fba1e2a48bee2',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/blob/master/cvpr2014_kantorov_paper.pdf'}},
#                                       'filetype': 'file',
#                                       'name': 'cvpr2014_kantorov_paper.pdf',
#                                       'sha': '823c3465a376145e7b2bda1a704ce2389b0c5162',
#                                       'size': 1818700,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/blob/master/cvpr2014_kantorov_poster.pdf'}},
#                                       'filetype': 'file',
#                                       'name': 'cvpr2014_kantorov_poster.pdf',
#                                       'sha': 'd77cd9b542a9fbdde87f3fd695d760f60689a573',
#                                       'size': 1417756,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/examples'}},
#                                       'filetype': 'dir',
#                                       'name': 'examples',
#                                       'num_files': 6,
#                                       'sha': 'c1ce7df0a27a39576031ccc03768d403eaf4e9a8',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/paper'}},
#                                       'filetype': 'dir',
#                                       'name': 'paper',
#                                       'num_files': 6,
#                                       'sha': '9ef416bec3337cebf5069d94317725974140b028',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/poster'}},
#                                       'filetype': 'dir',
#                                       'name': 'poster',
#                                       'num_files': 3,
#                                       'sha': '607adf306ef1ab395a41327910c7aa9409e3c43c',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/repro'}},
#                                       'filetype': 'dir',
#                                       'name': 'repro',
#                                       'num_files': 5,
#                                       'sha': '2da563b0a23c0a5adb55572e3526d9b1ea9d028d',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/src'}},
#                                       'filetype': 'dir',
#                                       'name': 'src',
#                                       'num_files': 4,
#                                       'sha': '895c8889bd832a65720af7d5f7c2823201fc504d',
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/vadimkantorov/fastvideofeat/tree/master/website'}},
#                                       'filetype': 'dir',
#                                       'name': 'website',
#                                       'num_files': 4,
#                                       'sha': '9321822e713f0dc205305320bcd302d8cf1c2529',
#                                       'type': 'code'}]},
#     'description': 'Efficient feature extraction, aggregation and '
#                    'classification for action recognition (CVPR 2014)',
#     'domain': {   'domain_prob': 0.8402786827030508,
#                   'domain_type': 'Computer Vision',
#                   'task': 'Image Classification',
#                   'task_prob': 0.3770447567258619},
#     'extraction': [   {   'frameworks': ['scikit-learn'],
#                           'issues': True,
#                           'readme': '# Information & Contact\n'
#                                     '\n'
#                                     'An earlier version of this code was used '
#                                     'to compute the results of the following '
#                                     'paper:\n'
#                                     '  \n'
#                                     '>"Efficient feature extraction, encoding '
#                                     'and classification for action '
#                                     'recognition",  \n'
#                                     'Vadim Kantorov, Ivan Laptev,  \n'
#                                     'In Proc. Computer Vision and Pattern '
#                                     'Recognition (CVPR), IEEE, 2014  \n'
#                                     '\n'
#                                     'If you use this code, please cite our '
#                                     'work:\n'
#                                     '\n'
#                                     '> @inproceedings{kantorov2014,  \n'
#                                     '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;author '
#                                     '= {Kantorov, V. and Laptev, I.},  \n'
#                                     '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;title '
#                                     '= {Efficient feature extraction, encoding '
#                                     'and classification for action '
#                                     'recognition},  \n'
#                                     '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;booktitle '
#                                     '= {Proc. Computer Vision and Pattern '
#                                     'Recognition (CVPR), IEEE, 2014},  \n'
#                                     '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;year '
#                                     '= {2014}  \n'
#                                     '}\n'
#                                     '\n'
#                                     'The paper and the poster are available at '
#                                     'the [project '
#                                     'webpage](http://www.di.ens.fr/willow/research/fastvideofeat) '
#                                     'or in this repository, the binaries are '
#                                     'published on the repository [releases '
#                                     'page](http://github.com/vadimkantorov/cvpr2014/releases), '
#                                     'the Hollywood-2 and HMDB-51 repro scripts '
#                                     'are in the [repro directory] '
#                                     '(http://github.com/vadimkantorov/cvpr2014/tree/master/repro/).\n'
#                                     '\n'
#                                     'Please submit bugs on '
#                                     '[GitHub](http://github.com/vadimkantorov/cvpr2014/issues) '
#                                     'directly.\n'
#                                     '\n'
#                                     'For any other question, please contact '
#                                     'Vadim Kantorov at vadim.kantorov@inria.fr '
#                                     'or vadim.kantorov@gmail.com.\n'
#                                     '\n'
#                                     '\n'
#                                     '# Description and usage\n'
#                                     '\n'
#                                     'We release two tools in this repository. '
#                                     'The first tool **fastvideofeat** is a '
#                                     'motion feature extractor based on motion '
#                                     'vectors from video compression '
#                                     'information. The second is a fast Fisher '
#                                     'vector computation tool **fastfv** that '
#                                     'uses vector SSE2 CPU instructions.\n'
#                                     '\n'
#                                     'We also release scripts (in the *repro* '
#                                     'directory) for reproducing our results on '
#                                     'Hollywood-2 dataset and on HMDB-51 '
#                                     'dataset.\n'
#                                     '\n'
#                                     'All code is released under the [MIT '
#                                     'license](http://github.com/vadimkantorov/cvpr2014/blob/master/LICENSE).\n'
#                                     '\n'
#                                     '### fastvideofeat\n'
#                                     '\n'
#                                     'The tool accepts a video file path as '
#                                     'input and writes descriptors to standard '
#                                     'output.  \n'
#                                     '##### Command-line options:\n'
#                                     '\n'
#                                     'Option | Description\n'
#                                     '--- | ---\n'
#                                     '--disableHOG | disables HOG descriptor '
#                                     'computation\n'
#                                     '--disableHOF | disables HOF descriptor '
#                                     'computation\n'
#                                     '--disableMBH | disables MBH descriptor '
#                                     'computation\n'
#                                     '-f 1-10 | restricts descriptor '
#                                     'computation to the given frame range\n'
#                                     '\n'
#                                     '**IMPORTANT** Frame range is specified in '
#                                     'terms of PTS (presentation time stamp) '
#                                     'which are usually equivalent to frame '
#                                     'indices, but not always. Beware. You can '
#                                     'inspect PTS values of the frames of the '
#                                     "video using ffmpeg's ffprobe (fourth "
#                                     'column):\n'
#                                     '\n'
#                                     '> $ ffprobe -print_format csv '
#                                     '-show_packets -select_streams 0 '
#                                     'video.mp4\n'
#                                     '\n'
#                                     'The output format (also reminded on '
#                                     'standard error):\n'
#                                     '\n'
#                                     '   ```#Descriptor format: xnorm ynorm '
#                                     'tnorm pts StartPTS EndPTS Xoffset Yoffset '
#                                     'PatchWidth PatchHeight hog (dim. 96) hof '
#                                     '(dim. 108) mbhx (dim. 96) mbhy (dim. '
#                                     '96)```\n'
#                                     '\n'
#                                     '  + **xnorm** and **ynorm** are the '
#                                     'normalized frame coordinates of the '
#                                     'spatio-temporal (s-t) patch  \n'
#                                     '  + **tnorm** and **pts** are the '
#                                     'normalized and unnormalized frame number '
#                                     'of the s-t patch center  \n'
#                                     '  + **StartPTS** and **EndPTS** are the '
#                                     'frame numbers of the first and last '
#                                     'frames of the s-t patch  \n'
#                                     '  + **Xoffset** and **Yoffset** are the '
#                                     'non-normalized frame coordinates of the '
#                                     's-t patch  \n'
#                                     '  + **PatchWidth** and **PatchHeight** '
#                                     'are the non-normalized width and height '
#                                     'of teh s-t patch\n'
#                                     '  + **descr** is the array of floats of '
#                                     'concatenated descriptors. The size of '
#                                     'this array depends on the enabled   '
#                                     'descriptor types. All values are from '
#                                     'zero to one. The first comment line '
#                                     'describes the enabled descriptor types, '
#                                     'their order in the array, and the '
#                                     'dimension of each descriptor in the '
#                                     'array.  \n'
#                                     '     \n'
#                                     'Every line on standard output corresponds '
#                                     'to an extracted descriptor of a patch anc '
#                                     'consists of tab-separated floats.  \n'
#                                     '\n'
#                                     '##### Examples:\n'
#                                     '  - Compute HOG, HOF, MBH and save the '
#                                     'descriptors in descriptors.txt:\n'
#                                     '    > $ ./fastvideofeat video.avi > '
#                                     'descriptors.txt\n'
#                                     '\n'
#                                     '  - Compute only HOF and MBH from the '
#                                     'first 600 frames and save the descriptors '
#                                     'in descriptors.txt:\n'
#                                     '    > $ ./fastvideofeat video.avi '
#                                     '--disableHOG -f 1-600 > descriptors.txt\n'
#                                     '\n'
#                                     'More examples in '
#                                     '*examples/compute_mpeg_features.sh*.\n'
#                                     '\n'
#                                     '##### Video format support\n'
#                                     "We've tested **fastvideofeat** only "
#                                     'videos encoded in H.264 and MPEG-4. '
#                                     'Whether motion vectors can be extracted '
#                                     'and processed depends completely on '
#                                     "FFmpeg's ability to put them into the "
#                                     "right structures. Last time I've checked "
#                                     'it was not working for VP9, for example. '
#                                     'And in general, video reading depends '
#                                     'fully on FFmpeg libraries.\n'
#                                     '\n'
#                                     '### fastfv\n'
#                                     'The tool accepts descriptors on the '
#                                     'standard input and writes Fisher vector '
#                                     '(FV) to the standard output. The tool '
#                                     'consumes GMM vocabs saved by Yael '
#                                     'library. A [sample '
#                                     'script](https://github.com/vadimkantorov/cvpr2014/blob/master/src/gmm_train.py) '
#                                     'to build GMM vocabs with Yael is '
#                                     'provided, as well as its [usage '
#                                     'example](https://github.com/vadimkantorov/cvpr2014/blob/master/examples/compute_fisher_vectors.sh).\n'
#                                     '\n'
#                                     '**IMPORTANT** The computed Fisher vectors '
#                                     'are non-normalized, apply signed square '
#                                     'rooting / power normalization, '
#                                     'L2-normalization, clipping etc before '
#                                     'training a classifier.\n'
#                                     '##### Command-line options:\n'
#                                     '\n'
#                                     'Option | Description\n'
#                                     '--- | ---\n'
#                                     '--xpos 0 | specifies the column with '
#                                     '**x** coordinate of the s-t patch in the '
#                                     'descriptor array\n'
#                                     '--ypos 1 | specifies the column with '
#                                     '**y** coordinate of the s-t patch in the '
#                                     'descriptor array\n'
#                                     '--tpos 2 | specifies the column with '
#                                     '**t** coordinate of the s-t patch in the '
#                                     'descriptor array\n'
#                                     '--knn 5 | FV parts corresponding to these '
#                                     'many closest GMM centroids will be '
#                                     'updated during processing of every input '
#                                     'descriptor\n'
#                                     '--vocab 10-105 10-105.hog.gmm | specifies '
#                                     'descriptor type location and path to GMM '
#                                     'vocab. This option is mandatory, and '
#                                     'several options of this kind are '
#                                     'allowed.\n'
#                                     '--enableflann 4 32 | use FLANN instead of '
#                                     'knn for descriptor attribution, first '
#                                     'argument is number of kd-trees, second '
#                                     'argument is number of checks performed '
#                                     'during attribution\n'
#                                     '--enablespatiotemporalgrids | enables '
#                                     'spatio-temporal grids: 1x1x1, 1x3x1, '
#                                     '1x1x2\n'
#                                     '--enablesecondorder | enables '
#                                     'second-order part of the Fisher vector\n'
#                                     '\n'
#                                     '##### Examples:\n'
#                                     '  - Compute Fisher vector:\n'
#                                     '    > $ zcat sample_features_mpeg4.txt.gz '
#                                     '| ../bin/fastfv --xpos 0 --ypos 1 --tpos '
#                                     '2 --enablespatiotemporalgrids '
#                                     '--enableflann 4 32 --vocab 10-105 '
#                                     'hollywood2_sample_vocabs/10-105.hog.gmm '
#                                     '--vocab 106-213 '
#                                     'hollywood2_sample_vocabs/106-213.hog.gmm '
#                                     '--vocab 214-309 '
#                                     'hollywood2_sample_vocabs/214-309.mbhx.gmm '
#                                     '--vocab 310-405 '
#                                     'hollywood2_sample_vocabs/310-405.mbhy.gmm '
#                                     '> fv.txt\n'
#                                     '\n'
#                                     '  - Build GMM vocab with Yael:\n'
#                                     '    > $ '
#                                     'PYTHONPATH=$(pwd)/../bin/dependencies/yael/yael:$PYTHONPATH '
#                                     'cat features*.gz | ../src/gmm_train.py '
#                                     '--gmm_ncomponents 256 --vocab 10-105 '
#                                     '10-105.hog.gmm\n'
#                                     '\n'
#                                     'Examples are explained in '
#                                     '*examples/compute_fisher_vector.sh*.\n'
#                                     '\n'
#                                     '##### Performance\n'
#                                     "We haven't observed enabling second order "
#                                     "boosts accuracy, so it's disabled by "
#                                     'default. Enabling second order part '
#                                     'increases Fisher vector size twice.\n'
#                                     '\n'
#                                     'Using simple knn descriptor attribution '
#                                     '(default) beats FLANN in speed by a '
#                                     'factor of two, yet leads to <1% accuracy '
#                                     "degradation. It's enabled by default "
#                                     'because of its speed. \n'
#                                     '\n'
#                                     'Enabling spatio-temporal grids (disabled '
#                                     'by default) is important for maximum '
#                                     'accuracy (~2% gain).\n'
#                                     '\n'
#                                     "If you use FLANN, it's the number of "
#                                     'checks that defines speed, try reducing '
#                                     'it to gain speed.\n'
#                                     '\n'
#                                     '# Building from source\n'
#                                     '\n'
#                                     'On both Linux and Windows, the binaries '
#                                     'will appear in *bin* after building. By '
#                                     'default, code links statically with '
#                                     'dependencies below, check Makefiles for '
#                                     'details.\n'
#                                     '\n'
#                                     'Dependencies for **fastvideofeat**:\n'
#                                     ' - opencv (http://opencv.org)\n'
#                                     ' - ffmpeg (http://ffmpeg.org)\n'
#                                     '\n'
#                                     'Dependencies for **fastfv**:\n'
#                                     ' - opencv (http://opencv.org)\n'
#                                     ' - yael '
#                                     '(http://gforge.inria.fr/projects/yael/), '
#                                     'ATLAS with LAPACK (required by yael)\n'
#                                     '\n'
#                                     'The code is known to work with OpenCV '
#                                     '2.4.9, FFmpeg 2.4, Yael 4.38, ATLAS '
#                                     '3.10.2, LAPACK 3.5.0. \n'
#                                     '\n'
#                                     '### Linux\n'
#                                     'Make sure you have the dependencies '
#                                     'installed and visible to g++ (a minimal '
#                                     'installation script is in the '
#                                     '*bin/dependencies* directory). Build the '
#                                     'tools by running **make**.\n'
#                                     '\n'
#                                     '### Windows\n'
#                                     'Only **fastvideofeat** builds and works '
#                                     "on Windows, **fastfv** doesn't build "
#                                     'because yael currently does not support '
#                                     'Windows.\n'
#                                     '\n'
#                                     'To build **fastvideofeat**, set in '
#                                     'Makefile the good paths to the '
#                                     'dependencies, processor architecture and '
#                                     'Visual C++ version, and run from an '
#                                     'appropriate Visual Studio Developer '
#                                     'Command Prompt (specifically, VS2013 x64 '
#                                     'Native Tools Command Prompt worked for '
#                                     'us):\n'
#                                     ' > $ nmake -f Makefile.nmake\n'
#                                     '\n'
#                                     '# Notes\n'
#                                     'For practical usage, software needs to be '
#                                     'modified to save and read features in '
#                                     'some binary format, because the overhead '
#                                     'on text file reading/writing is huge.\n'
#                                     '\n'
#                                     '# License and acknowledgements\n'
#                                     'All code and scripts are licensed under '
#                                     'the [MIT '
#                                     'license](http://github.com/vadimkantorov/cvpr2014/blob/master/LICENSE).\n'
#                                     '\n'
#                                     'We greatly thank [Heng '
#                                     'Wang](http://lear.inrialpes.fr/people/wang) '
#                                     'and [his '
#                                     'work](http://lear.inrialpes.fr/people/wang/improved_trajectories) '
#                                     'which was of significant help. \n',
#                           'readme_url': 'https://github.com/vadimkantorov/cvpr2014',
#                           'stars': 110,
#                           'type': 'github',
#                           'url': 'https://github.com/vadimkantorov/cvpr2014'}],
#     'name': 'Information & Contact',
#     'tags': [],
#     'visibility': {'license': 'MIT License', 'visibility': 'public'}}

# %%
# This block demonstrates using AIMMX for a subfolder within a repository

metadata = aimmx.repo_parse("https://github.com/tensorflow/models/tree/master/official/vision/image_classification")
pprint.pprint(metadata, indent=4)
# Out:
# Extracting AI model metadata from:  tensorflow/models
# {   'authors': [   {'github_id': 'nealwu', 'name': 'Neal Wu'},
#                    {'github_id': 'MarkDaoust', 'name': 'Mark Daoust'},
#                    {'github_id': 'tfboyd', 'name': 'Toby Boyd'},
#                    {'github_id': 'saberkun', 'name': 'Hongkun Yu'},
#                    {'github_id': 'pkulzc', 'name': 'pkulzc'},
#                    {'github_id': 'cshallue', 'name': 'Chris Shallue'},
#                    {   'email': 'taylorrobie@google.com',
#                        'github_id': 'robieta',
#                        'name': 'Taylor Robie'},
#                    {'github_id': 'derekjchow', 'name': 'derekjchow'},
#                    {   'github_id': 'tensorflower-gardener',
#                        'name': 'TensorFlower Gardener'},
#                    {'github_id': 'lukaszkaiser', 'name': 'Lukasz Kaiser'},
#                    {'github_id': 'guptapriya', 'name': 'guptapriya'},
#                    {'github_id': 'lamberta', 'name': 'Billy Lamberta'},
#                    {   'email': 'haoyuzhang@google.com',
#                        'github_id': 'haoyuz',
#                        'name': 'Haoyu Zhang'},
#                    {'github_id': 'reedwm', 'name': 'Reed'},
#                    {   'email': 'vivekmrathod@gmail.com',
#                        'github_id': 'tombstone',
#                        'name': 'vivek rathod'},
#                    {'github_id': 'asimshankar', 'name': 'Asim Shankar'},
#                    {'github_id': 'seemuch', 'name': 'Shining Sun'},
#                    {'github_id': 'martinwicke', 'name': 'Martin Wicke'},
#                    {'github_id': 'qlzh727', 'name': 'Qianli Scott Zhu'},
#                    {'github_id': 'jch1', 'name': 'Jonathan Huang'},
#                    {'github_id': 'karmel', 'name': 'Karmel Allison'},
#                    {'github_id': 'YknZhu', 'name': 'Yukun Zhu'},
#                    {'github_id': 'yeqingli', 'name': 'yeqingli'},
#                    {'github_id': 'bousmalis', 'name': 'Konstantinos Bousmalis'},
#                    {'github_id': 'joel-shor', 'name': 'Joel Shor'},
#                    {   'email': 'adai@google.com',
#                        'github_id': 'a-dai',
#                        'name': 'Andrew M Dai'},
#                    {'github_id': 'panyx0718', 'name': 'Xin Pan'},
#                    {'github_id': 'sguada', 'name': 'Sergio Guadarrama'},
#                    {'github_id': 'davidmochen', 'name': 'David M. Chen'},
#                    {'github_id': 'shlens', 'name': 'Jon Shlens'},
#                    {'github_id': 'raymond-yuan', 'name': 'Raymond Yuan'},
#                    {'github_id': 'dubey', 'name': 'Ayush Dubey'},
#                    {'github_id': 'itsmeolivia', 'name': 'Olivia'},
#                    {'github_id': 'alexgorban', 'name': 'Alexander Gorban'},
#                    {'github_id': 'yhliang2018', 'name': 'Yanhui Liang'},
#                    {'github_id': 'korrawat', 'name': 'James Pruegsanusak'},
#                    {'github_id': 'nnigania', 'name': 'nnigania'},
#                    {'github_id': 'k-w-w', 'name': 'Katherine Wu'},
#                    {'github_id': 'chenGitHuber', 'name': 'Chen Chen'},
#                    {   'email': 'vinh.nguyenx@gmail.com',
#                        'github_id': 'vinhngx',
#                        'name': 'Vinh Nguyen'},
#                    {   'email': 'menglong@google.com',
#                        'github_id': 'dreamdragon',
#                        'name': 'Menglong Zhu'},
#                    {'github_id': 'aquariusjay', 'name': 'aquariusjay'},
#                    {'github_id': 'isaprykin', 'name': 'Igor'},
#                    {'github_id': 'elibixby', 'name': 'Eli Bixby'},
#                    {'github_id': 'nmjohn', 'name': 'Nick Johnston'},
#                    {'github_id': 'rxsang', 'name': 'rxsang'},
#                    {'github_id': 'ilyamironov', 'name': 'Ilya Mironov'},
#                    {'github_id': 'waterson', 'name': 'Chris Waterson'},
#                    {'github_id': 'aselle', 'name': 'Andrew Selle'},
#                    {'github_id': 'plakal', 'name': 'Manoj Plakal'},
#                    {'github_id': 'rachellj218', 'name': 'Jing Li'},
#                    {'github_id': 'shizhiw', 'name': 'shizhiw'},
#                    {'github_id': 'andrefaraujo', 'name': 'André Araujo'},
#                    {'github_id': 'alanyee', 'name': 'Alan Yee'},
#                    {   'email': 'sussillo@google.com',
#                        'github_id': 'sussillo',
#                        'name': 'David Sussillo'},
#                    {   'email': 'yuefengz@google.com',
#                        'github_id': 'yuefengz',
#                        'name': 'Yuefeng Zhou'},
#                    {   'email': 'amit.anil.patankar@gmail.com',
#                        'github_id': 'av8ramit',
#                        'name': 'Amit Patankar'},
#                    {'github_id': 'calberti', 'name': 'calberti'},
#                    {'github_id': 'npapernot', 'name': 'Nicolas Papernot'},
#                    {   'email': 'dan@djoshea.com',
#                        'github_id': 'djoshea',
#                        'name': "Dan O'Shea"},
#                    {   'email': 'hongjunchoi@google.com',
#                        'github_id': 'hongjunChoi',
#                        'name': 'Hongjun Choi'},
#                    {'github_id': 'pengchongjin', 'name': 'Pengchong Jin'},
#                    {'github_id': 'josh11b', 'name': 'josh11b'},
#                    {   'email': 'dpwe@ee.columbia.edu',
#                        'github_id': 'dpwe',
#                        'name': 'Dan Ellis'},
#                    {   'github_id': 'vincentvanhoucke',
#                        'name': 'Vincent Vanhoucke'},
#                    {'github_id': 'ofirnachum', 'name': 'ofirnachum'},
#                    {'github_id': 'zongweiz', 'name': 'zongweiz'},
#                    {   'email': 'hjp709394@gmail.com',
#                        'github_id': 'hjp709394',
#                        'name': 'hjp709394'},
#                    {'github_id': 'gunan', 'name': 'Gunhan Gulsoy'},
#                    {   'email': 'gmarkhor@gmail.com',
#                        'github_id': 'vmarkovtsev',
#                        'name': 'Vadim Markovtsev'},
#                    {'github_id': 'alextamkin', 'name': 'alextamkin'},
#                    {   'email': 'jtunney@gmail.com',
#                        'github_id': 'jart',
#                        'name': 'Justine Tunney'},
#                    {   'email': 'suharshs@gmail.com',
#                        'github_id': 'suharshs',
#                        'name': 'Suharsh Sivakumar'},
#                    {'github_id': 'will-cromar', 'name': 'Will Cromar'},
#                    {   'email': 'yongzhe@google.com',
#                        'github_id': 'yongzhe2160',
#                        'name': 'Yongzhe Wang'},
#                    {'github_id': 'hsm207', 'name': 'hsm207'},
#                    {'github_id': 'AlexeyKurakin', 'name': 'Alexey Kurakin'},
#                    {'github_id': 'BarretZoph', 'name': 'Barret Zoph'},
#                    {'github_id': 'huihui-personal', 'name': 'huihui-personal'},
#                    {'github_id': 'allenlavoie', 'name': 'Allen Lavoie'},
#                    {'github_id': 'allenwang28', 'name': 'Allen Wang'},
#                    {'github_id': 'lindong28', 'name': 'Dong Lin'},
#                    {'github_id': 'Xhark', 'name': 'Jaehong Kim'},
#                    {   'email': 'sandler@google.com',
#                        'github_id': 'marksandler2',
#                        'name': 'Mark Sandler'},
#                    {'github_id': 'vladmos', 'name': 'Vladimir Moskva'},
#                    {'github_id': 'drpngx', 'name': 'Patrick Nguyen'},
#                    {'github_id': 'aman2930', 'name': 'Aman Gupta'},
#                    {'github_id': 'tae-jun', 'name': 'Taejun'},
#                    {'github_id': 'houtoms', 'name': 'Kaixi Hou'},
#                    {'github_id': 'DecentGradient', 'name': 'Joseph Friedman'},
#                    {   'email': 'rsepassi@google.com',
#                        'github_id': 'rsepassi',
#                        'name': 'Ryan Sepassi'},
#                    {'github_id': 'frankchn', 'name': 'Frank Chen'},
#                    {   'email': 'akshayka@cs.stanford.edu',
#                        'github_id': 'akshayka',
#                        'name': 'Akshay Agrawal'},
#                    {'github_id': 'jmchen-g', 'name': 'Jianmin Chen'},
#                    {   'email': 'm.rahmani@sahab.ir',
#                        'github_id': 'mrphoenix13',
#                        'name': 'Mostafa Rahmani'},
#                    {'github_id': 'mees', 'name': 'Oier Mees'},
#                    {'github_id': 'bfontain', 'name': 'Bruce Fontaine'},
#                    {   'email': 'derek.murray@gmail.com',
#                        'github_id': 'mrry',
#                        'name': 'Derek Murray'},
#                    {'github_id': 'protoget', 'name': 'Appledore'},
#                    {'github_id': 'jimmyyentran', 'name': 'jimmyyentran'},
#                    {'github_id': 'markomernick', 'name': 'Mark Omernick'},
#                    {   'email': 'pete@petewarden.com',
#                        'github_id': 'petewarden',
#                        'name': 'Pete Warden'},
#                    {'github_id': 'akuegel', 'name': 'Adrian Kuegel'},
#                    {'github_id': 'alexlee-gk', 'name': 'alexlee-gk'},
#                    {   'email': 'arinto@gmail.com',
#                        'github_id': 'arinto',
#                        'name': 'Arinto Murdopo'},
#                    {   'email': 'dave.andersen@gmail.com',
#                        'github_id': 'dave-andersen',
#                        'name': 'David Andersen'},
#                    {   'email': 'dheera at dheera dot net',
#                        'github_id': 'dheera',
#                        'name': 'Dheera Venkatraman'},
#                    {'github_id': 'justanhduc', 'name': 'Duc Nguyen'},
#                    {   'email': 'ggadde@google.com',
#                        'github_id': 'goldiegadde',
#                        'name': 'Goldie Gadde'},
#                    {'github_id': 'rezama', 'name': 'Reza Mahjourian'},
#                    {'github_id': 'sganeshb', 'name': 'sganeshb'},
#                    {'github_id': 's-gupta', 'name': 'Saurabh Gupta'},
#                    {'github_id': 'tayo', 'name': 'Tayo Oguntebi'},
#                    {'github_id': 'lintian06', 'name': 'Tian Lin'},
#                    {'github_id': 'Vyas9296', 'name': 'Vyas Adhikari'},
#                    {'github_id': 'swlsw', 'name': 'swlsw'},
#                    {'github_id': 'zanarmstrong', 'name': 'zan'},
#                    {'github_id': 'r2d4', 'name': 'Matt Rickard'},
#                    {'github_id': 'gjtucker', 'name': 'George'},
#                    {'github_id': 'yashk2810', 'name': 'Yash Katariya'},
#                    {   'email': 'alexandre.tp@gmail.com',
#                        'github_id': 'alextp',
#                        'name': 'Alexandre Passos'},
#                    {   'email': 'ATHundt@gmail.com',
#                        'github_id': 'ahundt',
#                        'name': 'Andrew Hundt'},
#                    {   'email': 'pathak.arkanath@gmail.com',
#                        'github_id': 'arkanath',
#                        'name': 'Arkanath Pathak'},
#                    {   'email': 'arvind@cs.umass.edu',
#                        'github_id': 'arvind2505',
#                        'name': 'Arvind Neelakantan'},
#                    {   'email': 'ben+github@benmabey.com',
#                        'github_id': 'bmabey',
#                        'name': 'Ben Mabey'},
#                    {   'email': 'chasun@microsoft.com',
#                        'github_id': 'snnn',
#                        'name': 'Changming Sun'},
#                    {'github_id': 'damienv-gh', 'name': 'damienv-gh'},
#                    {   'email': 'danabo@google.com',
#                        'github_id': 'danabo',
#                        'name': 'Daniel Abolafia'},
#                    {'github_id': 'mdanatg', 'name': 'Dan Moldovan'},
#                    {   'email': 'gogasca@google.com',
#                        'github_id': 'gogasca',
#                        'name': 'Gonzalo Gasca Meza'},
#                    {'github_id': 'haozha111', 'name': 'Haoliang Zhang'},
#                    {'github_id': 'buckman-google', 'name': 'buckman-google'},
#                    {'github_id': 'jazcollins', 'name': 'Jasmine Collins'},
#                    {'github_id': 'jlim262', 'name': 'JongYoon Lim'},
#                    {   'email': 'joshthoward@gmail.com',
#                        'github_id': 'joshthoward',
#                        'name': 'Josh Howard'},
#                    {   'email': 'k.nathaniel.tucker@gmail.com',
#                        'github_id': 'knathanieltucker',
#                        'name': 'K. Nathaniel Tucker'},
#                    {'github_id': 'clarkkev', 'name': 'Kevin Clark'},
#                    {'github_id': 'MTDzi', 'name': 'Maciej'},
#                    {   'email': 'marvin.teichmann@gmail.com',
#                        'github_id': 'MarvinTeichmann',
#                        'name': 'Marvin Teichmann'},
#                    {'github_id': 'orionr', 'name': 'Orion Reblitz-Richardson'},
#                    {'github_id': 'ananth1998', 'name': 'ananth1998'},
#                    {   'email': 'rzumer@tebako.net',
#                        'github_id': 'rzumer',
#                        'name': 'Raphaël Zumer'},
#                    {'github_id': 'samikama', 'name': 'Sami Kama'},
#                    {'github_id': 'stsievert', 'name': 'Scott Sievert'},
#                    {'github_id': 'sbrodehl', 'name': 'Sebastian Brodehl'},
#                    {   'email': 'grrwlf@gmail.com',
#                        'github_id': 'grwlf',
#                        'name': 'Sergey Mironov'},
#                    {'github_id': 'staff0rd', 'name': 'Stafford Williams'},
#                    {'github_id': 'vrv', 'name': 'Vijay Vasudevan'},
#                    {   'email': 'xcyan@umich.edu',
#                        'github_id': 'xcyan',
#                        'name': 'Xinchen Yan'},
#                    {   'email': 'yaroslavvb@gmail.com',
#                        'github_id': 'yaroslavvb',
#                        'name': 'Yaroslav Bulatov'},
#                    {'github_id': 'walkerlala', 'name': 'Yubin'},
#                    {'github_id': 'achowdhery', 'name': 'achowdhery'},
#                    {'github_id': 'anj-s', 'name': 'anj-s'},
#                    {'github_id': 'bananabowl', 'name': 'bananabowl'},
#                    {'github_id': 'mhyttsten', 'name': 'mhyttsten'},
#                    {'github_id': 'minoring', 'name': 'Minho Heo'},
#                    {'github_id': 'mloenow', 'name': 'mloenow'},
#                    {   'email': 'bugs@sauercrowdlabs.xyz',
#                        'github_id': 'sauercrowd',
#                        'name': 'Jonas Otten'},
#                    {   'github_id': 'adrianboguszewski',
#                        'name': 'Adrian Boguszewski'},
#                    {'github_id': 'aaroey', 'name': 'Guangda Lai'},
#                    {'github_id': 'iganichev', 'name': 'Igor Ganichev'},
#                    {'github_id': 'XinyueZ', 'name': 'ChrisDEV'},
#                    {   'email': 'david.dao@inf.ethz.ch',
#                        'github_id': 'daviddao',
#                        'name': '...'},
#                    {'github_id': 'rrtaylor', 'name': 'Richard Taylor'},
#                    {   'email': 'adityapaliwal95@gmail.com',
#                        'github_id': 'VastoLorde95',
#                        'name': 'Aditya Paliwal'},
#                    {'github_id': 'alanchiao', 'name': 'alanchiao'},
#                    {'github_id': 'algal', 'name': 'Alexis Gallagher'},
#                    {'github_id': 'DrewNF', 'name': 'Andrea Ferri'},
#                    {'github_id': 'aysark', 'name': 'Aysar'},
#                    {'github_id': 'charlesreid1', 'name': 'Chaz Reid'},
#                    {'github_id': 'chan1', 'name': 'Chris Han'},
#                    {   'email': 'chris.mattmann@gmail.com',
#                        'github_id': 'chrismattmann',
#                        'name': 'Chris Mattmann'},
#                    {'github_id': 'ctessum', 'name': 'Chris Tessum'},
#                    {   'email': 'cquiter+githubpublic@gmail.com',
#                        'github_id': 'crizCraig',
#                        'name': 'Craig Quiter'},
#                    {   'email': 'dakshvar22@gmail.com',
#                        'github_id': 'dakshvar22',
#                        'name': 'Daksh Varshneya'},
#                    {'github_id': 'dandouthit', 'name': 'Dan Douthit'},
#                    {   'email': 'warmspringwinds@gmail.com',
#                        'github_id': 'warmspringwinds',
#                        'name': 'Daniil Pakhomov'},
#                    {   'email': 'david@weekly.org',
#                        'github_id': 'dweekly',
#                        'name': 'David E. Weekly'},
#                    {   'email': 'dieterich.lawson@gmail.com',
#                        'github_id': 'dieterichlawson',
#                        'name': 'Dieterich Lawson'},
#                    {'github_id': 'edouardfouche', 'name': 'Edouard Fouché'},
#                    {'github_id': 'ema987', 'name': 'Emanuele'},
#                    {   'email': 'george@metaworld.me',
#                        'github_id': 'cheshire',
#                        'name': 'George Karpenkov'},
#                    {   'email': 'henry.elder@adaptcentre.ie',
#                        'github_id': 'Henry-E',
#                        'name': 'Henry-E'},
#                    {'github_id': 'sculd', 'name': 'Hyungjun Lim'},
#                    {'github_id': 'shamoya', 'name': 'Ido Shamay'},
#                    {'github_id': 'moonboots', 'name': 'Jack Zhang'},
#                    {'github_id': 'hellojas', 'name': 'Jasmine'},
#                    {   'email': 'github@yjmade.net',
#                        'github_id': 'yjmade',
#                        'name': 'Jay Young'},
#                    {   'email': 'deklerk@google.com',
#                        'github_id': 'jadekler',
#                        'name': 'Jean de Klerk'},
#                    {   'email': 'jeremy@lewi.us',
#                        'github_id': 'jlewi',
#                        'name': 'Jeremy Lewi'},
#                    {'github_id': 'snurkabill', 'name': 'Jiří Vahala'},
#                    {'github_id': 'jonsafari', 'name': 'Jon'},
#                    {   'email': 'joju@inano.au.dk',
#                        'github_id': 'JonathanJuhl',
#                        'name': 'Jonathan juhl'},
#                    {   'email': 'pandevirus@gmail.com',
#                        'github_id': 'kemaswill',
#                        'name': 'Junwei Pan'},
#                    {'github_id': 'LiberiFatali', 'name': 'LiberiFatali'},
#                    {   'email': 'lucky@couture.ai',
#                        'github_id': 'lucky096',
#                        'name': 'Lucky Srivastava'},
#                    {'github_id': 'lababidi', 'name': 'Mahmoud Lababidi'},
#                    {   'github_id': 'mari-linhares',
#                        'name': 'Marianne Linhares Monteiro'},
#                    {   'github_id': 'MatthiasWinkelmann',
#                        'name': 'Matthias Winkelmann'},
#                    {   'email': 'mfigurnov@google.com',
#                        'github_id': 'mfigurnov',
#                        'name': 'Michael Figurnov'},
#                    {   'email': 'mohammad.n@gmail.com',
#                        'github_id': 'norouzi',
#                        'name': 'Mohammad Norouzi'},
#                    {   'email': 'naurril@gmail.com',
#                        'github_id': 'naurril',
#                        'name': 'Naurril'},
#                    {   'email': 'nirum@google.com',
#                        'github_id': 'nirum',
#                        'name': 'Niru Maheswaranathan'},
#                    {   'email': 'pranay360@gmail.com',
#                        'github_id': 'pranay360',
#                        'name': 'Pranay Mathur'},
#                    {   'email': 'rachelim@cs.stanford.edu',
#                        'github_id': 'rachellim',
#                        'name': 'Rachel Lim'},
#                    {'github_id': 'theraysmith', 'name': 'theraysmith'},
#                    {   'email': 'rohan100jain@gmail.com',
#                        'github_id': 'rohan100jain',
#                        'name': 'Rohan Jain'},
#                    {'github_id': 'SNeugber', 'name': 'Samuel Neugber'},
#                    {   'email': 'skligys@google.com',
#                        'github_id': 'skkligys',
#                        'name': 'Skirmantas Kligys'},
#                    {'github_id': 'slavpetrov', 'name': 'Slav Petrov'},
#                    {'github_id': 'sshrdp', 'name': 'Soroush Radpour'},
#                    {   'email': 'me@stevenhickson.com',
#                        'github_id': 'StevenHickson',
#                        'name': 'Steven Hickson'},
#                    {   'email': 'swaroopgj@gmail.com',
#                        'github_id': 'swaroopgj',
#                        'name': 'Swaroop Guntupalli'},
#                    {'github_id': 'terryykoo', 'name': 'Terry Koo'},
#                    {   'email': 'thibaut.mattio@gmail.com',
#                        'github_id': 'tmattio',
#                        'name': 'Thibaut Mattio'},
#                    {'github_id': 'WillAyd', 'name': 'William Ayd'},
#                    {'github_id': 'wolffg', 'name': 'Wolff Dobson'},
#                    {   'email': 'ywryoo@gmail.com',
#                        'github_id': 'ywryoo',
#                        'name': 'Ryangwook Ryoo'},
#                    {'github_id': 'yk5', 'name': 'Younghee Kwon'},
#                    {'github_id': 'ppwwyyxx', 'name': 'Yuxin Wu'},
#                    {'github_id': 'yuyuz', 'name': 'Yuyu Zhang'},
#                    {   'email': 'zach@protechig.com',
#                        'github_id': 'zachary-russell',
#                        'name': 'Zachary Russell'},
#                    {   'email': 'amir.bar@cs.tau.ac.il',
#                        'github_id': 'amirbar',
#                        'name': 'Amir Bar'},
#                    {   'email': 'cclauss@me.com',
#                        'github_id': 'cclauss',
#                        'name': 'Christian Clauss'},
#                    {'github_id': 'chsin', 'name': 'chsin'},
#                    {'github_id': 'jzhugithub', 'name': 'jzhugithub'},
#                    {   'email': 'kvn.hou@gmail.com',
#                        'github_id': 'kaiix',
#                        'name': 'kaiix'},
#                    {'github_id': 'liangxiao05', 'name': 'liangxiao05'},
#                    {'github_id': 'talkdirty', 'name': 'Georg Grab'},
#                    {   'github_id': 'tf-models-copybara-bot',
#                        'name': 'tf-models-copybara-bot'},
#                    {'github_id': 'thess24', 'name': 'thess24'},
#                    {'github_id': 'xiangjinwu', 'name': 'xiangjinwu'},
#                    {   'email': '2549594681@qq.com',
#                        'github_id': 'matiji66',
#                        'name': 'yinchunfeng'},
#                    {   'email': 'gatoatigrado@gmail.com',
#                        'github_id': 'gatoatigrado',
#                        'name': 'zora tung'},
#                    {   'email': 'awsomekde@gmail.com',
#                        'github_id': 'callofdutyops',
#                        'name': '黄璞'},
#                    {'github_id': 'saeta', 'name': 'Brennan Saeta'},
#                    {'github_id': 'dmrd', 'name': 'David Dohan'},
#                    {'github_id': 'dthkao', 'name': 'David T.H. Kao'},
#                    {'github_id': 'dmansfield', 'name': 'David Mansfield'},
#                    {'github_id': 'jaingaurav', 'name': 'Gaurav Jain'},
#                    {'github_id': 'lukelafountaine', 'name': 'Luke LaFountaine'},
#                    {'github_id': 'leonardgithub', 'name': 'Leonard Lee'},
#                    {   'email': 'hypernovagama@gmail.com',
#                        'github_id': 'inflation',
#                        'name': 'Inflation'},
#                    {   'email': 'ajschumacher@gmail.com',
#                        'github_id': 'ajschumacher',
#                        'name': 'Aaron Schumacher'},
#                    {   'email': 'a.rasheed@tc-sa.com',
#                        'github_id': 'TwistedHardware',
#                        'name': 'Abdullah Alrasheed'},
#                    {'github_id': 'abhinavsagar', 'name': 'Abhinav Sagar'},
#                    {'github_id': 'angryadam', 'name': 'Adam Myers'},
#                    {   'email': 'a.t.sheehan@gmail.com',
#                        'github_id': 'atsheehan',
#                        'name': 'Adam Sheehan'},
#                    {'github_id': 'udnaan', 'name': 'Adnan'},
#                    {'github_id': 'iakashpaul', 'name': 'Akash'},
#                    {'github_id': 'apbusia', 'name': 'Akosua'},
#                    {'github_id': 'aarorasimbulus', 'name': 'Akshit Arora'},
#                    {'github_id': 'mackeya-google', 'name': 'mackeya-google'},
#                    {   'email': 'alexalemi@gmail.com',
#                        'github_id': 'alexalemi',
#                        'name': 'Alex Alemi'},
#                    {'github_id': 'AsterAI', 'name': 'Alexandr Baranezky'},
#                    {   'github_id': 'AndreiCostinescu',
#                        'name': 'Andrei Costinescu'},
#                    {'github_id': 'andrewgilbert12', 'name': 'Andrew Gilbert'},
#                    {'github_id': 'aneliaangelova', 'name': 'aneliaangelova'},
#                    {'github_id': 'angusmcleod', 'name': 'Angus McLeod'},
#                    {   'email': 'aniruddhastapas@gmail.com',
#                        'github_id': 'Aniruddha-Tapas',
#                        'name': 'Aniruddha Tapas'},
#                    {   'email': 'ajtatowicz@gmail.com',
#                        'github_id': 'Anthony-Tatowicz',
#                        'name': 'Anthony Tatowicz Jr'},
#                    {   'email': 'kamikazeanuj@gmail.com',
#                        'github_id': 'alasin',
#                        'name': 'Anuj Pahuja'},
#                    {   'email': 'a.petrova.ds@gmail.com',
#                        'github_id': 'playadust',
#                        'name': 'Anya Petrova'},
#                    {   'email': 'arokem@gmail.com',
#                        'github_id': 'arokem',
#                        'name': 'Ariel Rokem'},
#                    {   'email': 'github+spam.or.ham@arne.cl',
#                        'github_id': 'arne-cl',
#                        'name': 'Arne Neumann'},
#                    {   'github_id': 'arsalan-mousavian',
#                        'name': 'Arsalan Mousavian'},
#                    {   'email': 'artitw@gmail.com',
#                        'github_id': 'artitw',
#                        'name': "Artit 'Art' Wangperawong"},
#                    {'github_id': 'arvind385801', 'name': 'arvind385801'},
#                    {   'email': 'ashley@inp.io',
#                        'github_id': 'awilliamson',
#                        'name': 'Ashley Williamson'},
#                    {   'email': 'august.janse@gmail.com',
#                        'github_id': 'augustjanse',
#                        'name': 'August Janse'},
#                    {'github_id': 'BMDan', 'name': 'Dan Reif'},
#                    {   'email': 'me@byjiang.com',
#                        'github_id': 'BoyuanJiang',
#                        'name': 'Boyuan'},
#                    {'github_id': 'bapfeld', 'name': 'Brendan Apfeld'},
#                    {'github_id': 'brettkoonce', 'name': 'brett koonce'},
#                    {'github_id': 'brilee', 'name': 'Brian Lee'},
#                    {'github_id': 'Buzzology', 'name': 'Buzzology'},
#                    {'github_id': 'ByeongjooAhn', 'name': 'Byeongjoo Ahn'},
#                    {'github_id': 'ConceitedCode', 'name': 'Cameron Rudnick'},
#                    {'github_id': 'SA-Framework', 'name': 'SA-Framework'},
#                    {'github_id': 'cbfinn', 'name': 'Chelsea Finn'},
#                    {'github_id': 'chenxi116', 'name': 'Chenxi Liu'},
#                    {'github_id': 'cpandar', 'name': 'Chethan Pandarinath'},
#                    {'github_id': 'chr1sj0nes', 'name': 'Chris Jones'},
#                    {   'email': 'cjzhang@uwaterloo.ca',
#                        'github_id': 'czhang96',
#                        'name': 'Chris Zhang'},
#                    {'github_id': '23pointsNorth', 'name': 'Daniel Angelov'},
#                    {'github_id': 'danieljl', 'name': 'Daniel Julius Lasiman'},
#                    {   'email': 'me@danieldk.eu',
#                        'github_id': 'danieldk',
#                        'name': 'Daniël de Kok'},
#                    {'github_id': 'davidbrai', 'name': 'David Brailovsky'},
#                    {'github_id': 'Hanqing-Sun', 'name': 'Hanqing Sun'},
#                    {'github_id': 'gharibian', 'name': 'Dero Gharibian'},
#                    {'github_id': 'devanshdalal', 'name': 'Devansh D.'},
#                    {'github_id': 'Devansh-S', 'name': 'Devansh Singh'},
#                    {   'email': 'dmitrij.murygin@bk.ru',
#                        'github_id': 'Vooblin',
#                        'name': 'Dmitrii Murygin'},
#                    {   'email': 'yutkinn@gmail.com',
#                        'github_id': 'yutkin',
#                        'name': 'Dmitry Yutkin'},
#                    {   'email': 'dsc@dosc.net',
#                        'github_id': 'domschl',
#                        'name': 'Dominik Schlösser'},
#                    {'github_id': 'donkirkby', 'name': 'Don Kirkby'},
#                    {   'email': 'dougal@gmail.com',
#                        'github_id': 'dougalsutherland',
#                        'name': 'Dougal J. Sutherland'},
#                    {'github_id': 'dwightjl', 'name': 'Dwight J Lyle'},
#                    {'github_id': 'e7dud7e', 'name': 'Eddy Shyu'},
#                    {'github_id': 'Egor-Krivov', 'name': 'Egor Krivov'},
#                    {'github_id': 'elielhojman', 'name': 'Eliel Hojman'},
#                    {'github_id': 'emsansone', 'name': 'Emanuele Sansone'},
#                    {   'email': 'em@kth.se',
#                        'github_id': 'EmilStenstrom',
#                        'name': 'Emil Stenström'},
#                    {'github_id': 'strubell', 'name': 'Emma Strubell'},
#                    {   'github_id': 'erssebaggala',
#                        'name': 'Emmanuel Robert Ssebaggala'},
#                    {   'email': 'ersho.ge@gmail.com',
#                        'github_id': 'Ersho',
#                        'name': 'Erekle'},
#                    {'github_id': 'EvanKepner', 'name': 'Evan Kepner'},
#                    {   'email': 'ewanlee@yeah.net',
#                        'github_id': 'ewanlee',
#                        'name': 'Ewanlee'},
#                    {'github_id': 'fmannan', 'name': 'Fahim Mannan'},
#                    {'github_id': 'fangweili', 'name': 'Fangwei Li'},
#                    {'github_id': 'feynmanliang', 'name': 'Feynman Liang'},
#                    {   'email': 'filipe.jesus@usp.br',
#                        'github_id': 'filipefilardi',
#                        'name': 'Filipe Filardi'},
#                    {   'email': 'franck@verrot.fr',
#                        'github_id': 'franckverrot',
#                        'name': 'Franck Verrot'},
#                    {   'email': 'gblin75468@gmail.com',
#                        'github_id': 'GBLin5566',
#                        'name': 'Chien-Fu Lin'},
#                    {   'email': 'georgw7777@gmail.com',
#                        'github_id': 'georgw777',
#                        'name': 'Georg Wölflein'},
#                    {'github_id': 'NescobarAlopLop', 'name': 'George K'},
#                    {'github_id': 'gwulfs', 'name': 'Gideon Wulfsohn'},
#                    {   'github_id': 'gideaoabreu',
#                        'name': 'Gideão Pelegrino de Abreu'},
#                    {   'email': 'g@raphaelli.com',
#                        'github_id': 'graphaelli',
#                        'name': 'Gil Raphaelli'},
#                    {   'email': 'iepathos@gmail.com',
#                        'github_id': 'iepathos',
#                        'name': 'Glen Baker'},
#                    {'github_id': 'gnprice', 'name': 'Greg Price'},
#                    {'github_id': 'gyang274', 'name': 'Guang Yang'},
#                    {'github_id': 'wileeam', 'name': 'Guillermo Rodriguez Cano'},
#                    {   'email': 'yejun.guo@intel.com',
#                        'github_id': 'guoyejun',
#                        'name': 'Guo Yejun (郭叶军)'},
#                    {   'email': 'haichaoyu3@gmail.com',
#                        'github_id': 'haichaoyu',
#                        'name': 'Haichao Yu'},
#                    {   'email': 'kongsea@gmail.com',
#                        'github_id': 'Kongsea',
#                        'name': 'Kongsea'},
#                    {'github_id': 'zsdonghao', 'name': 'Hao'},
#                    {   'email': 'harshuljain1393@gmail.com',
#                        'github_id': 'harshul1610',
#                        'name': 'Harshul jain'},
#                    {'github_id': 'HelgeS', 'name': 'HelgeS'},
#                    {'github_id': 'qwook', 'name': 'Henry'},
#                    {'github_id': 'chantera', 'name': 'Hiroki Teranishi'},
#                    {   'email': 'liuhougang6@126.com',
#                        'github_id': 'hougangliu',
#                        'name': 'Hougang Liu'},
#                    {   'email': 'jaeman1.park@samsung.com',
#                        'github_id': 'parkjaeman',
#                        'name': 'Jaeman'},
#                    {   'email': 'heythisischo@gmail.com',
#                        'github_id': 'j-min',
#                        'name': 'Jaemin Cho'},
#                    {'github_id': 'jaewoosong', 'name': 'Jaewoo Song'},
#                    {   'email': 'darthdeus@gmail.com',
#                        'github_id': 'darthdeus',
#                        'name': 'Jakub Arnold'},
#                    {'github_id': 'jameshwang', 'name': 'James Hwang'},
#                    {   'email': 'jamie@iamjamiecooke.com',
#                        'github_id': 'jubjamie',
#                        'name': 'Jamie Cooke'},
#                    {'github_id': 'j143', 'name': 'j143'},
#                    {   'email': 'credentiality@gmail.com',
#                        'github_id': 'credentiality',
#                        'name': 'credentiality'},
#                    {   'email': 'jason860421@gmail.com',
#                        'github_id': 'JasonLiTW',
#                        'name': 'Jason421'},
#                    {'github_id': 'jsnydes', 'name': 'Jeff Snyder'},
#                    {'github_id': 'jeuvilla', 'name': 'jeuvilla'},
#                    {'github_id': 'jnieuviarts', 'name': 'Jerry Nieuviarts'},
#                    {   'email': 'theJiangYu@gmail.com',
#                        'github_id': 'theJiangYu',
#                        'name': 'Jiang Yu'},
#                    {   'email': 'zhoulong.jiang@intel.com',
#                        'github_id': 'jzhoulon',
#                        'name': 'jzhoulon'},
#                    {   'email': 'jima@comware.com.au',
#                        'github_id': 'jalateras',
#                        'name': 'Jim Alateras'},
#                    {'github_id': 'JimHeo', 'name': 'JimintheBox'},
#                    {'github_id': 'jsimsa', 'name': 'Jiri Simsa'},
#                    {'github_id': 'johnarevalo', 'name': 'John Arevalo'},
#                    {'github_id': 'jonasrauber', 'name': 'Jonas Rauber'},
#                    {   'email': 'Jmitchell1991@gmail.com',
#                        'github_id': 'JonathanCMitchell',
#                        'name': 'Jonathan Mitchell'},
#                    {'github_id': 'williford', 'name': 'Jonathan R. Williford'},
#                    {   'email': 'wookayin@gmail.com',
#                        'github_id': 'wookayin',
#                        'name': 'Jongwook Choi'},
#                    {'github_id': 'jbaiocchi', 'name': 'Jose Baiocchi'},
#                    {'github_id': 'random-forests', 'name': 'Josh Gordon'},
#                    {   'email': 'jgagnonmarchand@gmail.com',
#                        'github_id': 'JulesGM',
#                        'name': 'Jules Gagnon-Marchand'},
#                    {   'email': 'karanbleep@gmail.com',
#                        'github_id': 'karanchahal',
#                        'name': 'Karanbir Chahal'},
#                    {'github_id': 'n-kats', 'name': 'Katsunori Nakanishi'},
#                    {   'email': 'kazunori279@gmail.com',
#                        'github_id': 'kazunori279',
#                        'name': 'Kaz Sato'},
#                    {   'email': 'ken@kawamoto.co.uk',
#                        'github_id': 'kenkawakenkenke',
#                        'name': 'Ken Kawamoto'},
#                    {   'email': 'sodetz@purdue.edu',
#                        'github_id': 'kcsodetz',
#                        'name': 'Ken Sodetz'},
#                    {   'email': 'kepingwang@yahoo.com',
#                        'github_id': 'kepingwang',
#                        'name': 'Keping Wang'},
#                    {   'email': 'krshna@stanford.edu',
#                        'github_id': 'krishpop',
#                        'name': 'Krishnan Srinivasan'},
#                    {'github_id': 'rockokw', 'name': 'Kwame Wright'},
#                    {'github_id': 'legel', 'name': 'Lance Legel'},
#                    {'github_id': 'laurent-dinh', 'name': 'Laurent Dinh'},
#                    {'github_id': 'lilao', 'name': 'Li Lao'},
#                    {   'email': 'liampronan@gmail.com',
#                        'github_id': 'Liampronan',
#                        'name': 'Liam Ronan'},
#                    {'github_id': 'lilipads', 'name': 'Lili Jiang'},
#                    {'github_id': 'ffmpbgrnn', 'name': 'Linchao Zhu'},
#                    {   'email': 'liviobs@gmail.com',
#                        'github_id': 'liviosoares',
#                        'name': 'Livio Soares'},
#                    {'github_id': 'Lotte1990', 'name': 'Lotte1990'},
#                    {'github_id': 'madhurapande19', 'name': 'Madhura Pande'},
#                    {   'email': 'malcolm@ieee.org',
#                        'github_id': 'MalcolmSlaney',
#                        'name': 'Malcolm Slaney'},
#                    {   'email': 'keveman@gmail.com',
#                        'github_id': 'keveman',
#                        'name': 'Manjunath Kudlur'},
#                    {'github_id': 'marcbelmont', 'name': 'Marc Belmont'},
#                    {'github_id': 'martinkersner', 'name': 'Martin Kersner'},
#                    {'github_id': 'nightscape', 'name': 'Martin Mauch'},
#                    {   'email': 'mghenis@gmail.com',
#                        'github_id': 'MaxGhenis',
#                        'name': 'Max Ghenis'},
#                    {   'email': 'mnatraj@google.com',
#                        'github_id': 'MeghnaNatraj',
#                        'name': 'Meghna Natraj'},
#                    {'github_id': 'MehdiShz', 'name': 'Mehdi Sharifzadeh'},
#                    {'github_id': 'mgruben', 'name': 'Michael Gruben-Trejo'},
#                    {'github_id': 'kopankom', 'name': 'Michał Kopańko'},
#                    {   'email': 'nick.drabovich@amd.com',
#                        'github_id': 'MikalaiDrabovich',
#                        'name': 'Mikalai Drabovich'},
#                    {'github_id': 'marpaia', 'name': 'Mike Arpaia'}],
#     'definition': {   'code': [   {   'description': 'Models and examples '
#                                                      'built with TensorFlow',
#                                       'frameworks': [   'Keras',
#                                                         'NLTK',
#                                                         'scikit-learn',
#                                                         'TensorFlow'],
#                                       'language': 'Python',
#                                       'license': 'Apache License 2.0',
#                                       'name': 'models',
#                                       'owner': 'tensorflow',
#                                       'pushed_at': '2020-01-15 10:27:21+00:00',
#                                       'repo_type': 'github',
#                                       'stars': 61091,
#                                       'type': 'repo',
#                                       'url': 'https://github.com/tensorflow/models/tree/master/official/vision/image_classification'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/__init__.py'}},
#                                       'filetype': 'file',
#                                       'name': '__init__.py',
#                                       'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#                                       'size': 0,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/cifar_preprocessing.py'}},
#                                       'filetype': 'file',
#                                       'name': 'cifar_preprocessing.py',
#                                       'sha': 'dcf174b9cc0ac2046e7ffe5248caf29b4fe16e15',
#                                       'size': 5887,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/common.py'}},
#                                       'filetype': 'file',
#                                       'name': 'common.py',
#                                       'sha': '4e560f1152d8ca1ee4ac1d98b2d63b583c722b02',
#                                       'size': 19500,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/common_test.py'}},
#                                       'filetype': 'file',
#                                       'name': 'common_test.py',
#                                       'sha': 'a6a967e8aa602749590cbdfa0b9b8c079f17692f',
#                                       'size': 3680,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/imagenet_preprocessing.py'}},
#                                       'filetype': 'file',
#                                       'name': 'imagenet_preprocessing.py',
#                                       'sha': '6758cd21f553ea96c598bc0b02b3a41be4750d1f',
#                                       'size': 21485,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/mnist_main.py'}},
#                                       'filetype': 'file',
#                                       'name': 'mnist_main.py',
#                                       'sha': '9f72c04bae63bbbfcee7c89a10d04158a9d19652',
#                                       'size': 5978,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/mnist_test.py'}},
#                                       'filetype': 'file',
#                                       'name': 'mnist_test.py',
#                                       'sha': '0452e406c456067e6f1ae57e67677a943326e976',
#                                       'size': 2908,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_cifar_main.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_cifar_main.py',
#                                       'sha': '41ace8e76597a05f7e8b6c06b55e0ac8b2f22f97',
#                                       'size': 9020,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_cifar_model.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_cifar_model.py',
#                                       'sha': '1b507381f1b6907fdfb078d8316f3621a9e2b8f7',
#                                       'size': 10366,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_cifar_test.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_cifar_test.py',
#                                       'sha': '8ef39607ee6ee8f14485b388a054c9611174c720',
#                                       'size': 5834,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_ctl_imagenet_main.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_ctl_imagenet_main.py',
#                                       'sha': '9d50f39f91b30100dfe1024c700d863b1264e994',
#                                       'size': 16127,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_ctl_imagenet_test.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_ctl_imagenet_test.py',
#                                       'sha': '85fc6ad3b74d2e4374b8848a3063122041d5f330',
#                                       'size': 3225,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_imagenet_main.py'}},
#                                       'filetype': 'file',
#                                       'name': 'resnet_imagenet_main.py',
#                                       'sha': '5c1c76df31065ddb3d2f2c830534f133b7ecf5b2',
#                                       'size': 13721,
#                                       'type': 'code'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/tensorflow/models/blob/master/official/vision/image_classification/resnet_imagenet_test.py'}},
# ...
#                                     'in\n'
#                                     '[`resnet_cifar_model.py`](./resnet_cifar_model.py), '
#                                     'and the ImageNet version\n'
#                                     'uses a ResNet50 model implemented in '
#                                     '[`resnet_model.py`](./resnet_model.py).\n'
#                                     '\n'
#                                     'To use\n'
#                                     'either dataset, make sure that you have '
#                                     'the latest version of TensorFlow\n'
#                                     'installed and\n'
#                                     '[add the models folder to your Python '
#                                     'path](/official/#running-the-models).\n'
#                                     '\n'
#                                     '### Pretrained Models\n'
#                                     '\n'
#                                     '* [ResNet50 '
#                                     'Checkpoints](https://storage.googleapis.com/cloud-tpu-checkpoints/resnet/resnet50.tar.gz)\n'
#                                     '\n'
#                                     '* ResNet50 TFHub: [feature '
#                                     'vector](https://tfhub.dev/tensorflow/resnet_50/feature_vector/1)\n'
#                                     'and '
#                                     '[classification](https://tfhub.dev/tensorflow/resnet_50/classification/1)\n'
#                                     '\n'
#                                     '### CIFAR-10\n'
#                                     '\n'
#                                     'Download and extract the CIFAR-10 data. '
#                                     'You can use the following script:\n'
#                                     '```bash\n'
#                                     'python '
#                                     '../../r1/resnet/cifar10_download_and_extract.py\n'
#                                     '```\n'
#                                     '\n'
#                                     'After you download the data, you can run '
#                                     'the program by:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_cifar_main.py\n'
#                                     '```\n'
#                                     '\n'
#                                     'If you did not use the default directory '
#                                     'to download the data, specify the\n'
#                                     'location with the `--data_dir` flag, '
#                                     'like:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_cifar_main.py '
#                                     '--data_dir=/path/to/cifar\n'
#                                     '```\n'
#                                     '\n'
#                                     '### ImageNet Training\n'
#                                     '\n'
#                                     'Download the ImageNet dataset and convert '
#                                     'it to TFRecord format.\n'
#                                     'The following '
#                                     '[script](https://github.com/tensorflow/tpu/blob/master/tools/datasets/imagenet_to_gcs.py)\n'
#                                     'and '
#                                     '[README](https://github.com/tensorflow/tpu/tree/master/tools/datasets#imagenet_to_gcspy)\n'
#                                     'provide a few options.\n'
#                                     '\n'
#                                     'Once your dataset is ready, you can begin '
#                                     'training the model as follows:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_imagenet_main.py\n'
#                                     '```\n'
#                                     '\n'
#                                     'Again, if you did not download the data '
#                                     'to the default directory, specify the\n'
#                                     'location with the `--data_dir` flag:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_imagenet_main.py '
#                                     '--data_dir=/path/to/imagenet\n'
#                                     '```\n'
#                                     '\n'
#                                     'There are more flag options you can '
#                                     'specify. Here are some examples:\n'
#                                     '\n'
#                                     '- `--use_synthetic_data`: when set to '
#                                     'true, synthetic data, rather than real\n'
#                                     'data, are used;\n'
#                                     '- `--batch_size`: the batch size used for '
#                                     'the model;\n'
#                                     '- `--model_dir`: the directory to save '
#                                     'the model checkpoint;\n'
#                                     '- `--train_epochs`: number of epoches to '
#                                     'run for training the model;\n'
#                                     '- `--train_steps`: number of steps to run '
#                                     'for training the model. We now only\n'
#                                     'support a number that is smaller than the '
#                                     'number of batches in an epoch.\n'
#                                     '- `--skip_eval`: when set to true, '
#                                     'evaluation as well as validation during\n'
#                                     'training is skipped\n'
#                                     '\n'
#                                     'For example, this is a typical command '
#                                     'line to run with ImageNet data with\n'
#                                     'batch size 128 per GPU:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python -m resnet_imagenet_main \\\n'
#                                     '    --model_dir=/tmp/model_dir/something '
#                                     '\\\n'
#                                     '    --num_gpus=2 \\\n'
#                                     '    --batch_size=128 \\\n'
#                                     '    --train_epochs=90 \\\n'
#                                     '    --train_steps=10 \\\n'
#                                     '    --use_synthetic_data=false\n'
#                                     '```\n'
#                                     '\n'
#                                     'See [`common.py`](common.py) for full '
#                                     'list of options.\n'
#                                     '\n'
#                                     '### Using multiple GPUs\n'
#                                     '\n'
#                                     'You can train these models on multiple '
#                                     'GPUs using `tf.distribute.Strategy` API.\n'
#                                     'You can read more about them in this\n'
#                                     '[guide](https://www.tensorflow.org/guide/distribute_strategy).\n'
#                                     '\n'
#                                     'In this example, we have made it easier '
#                                     'to use is with just a command line flag\n'
#                                     '`--num_gpus`. By default this flag is 1 '
#                                     'if TensorFlow is compiled with CUDA,\n'
#                                     'and 0 otherwise.\n'
#                                     '\n'
#                                     '- --num_gpus=0: Uses '
#                                     'tf.distribute.OneDeviceStrategy with CPU '
#                                     'as the device.\n'
#                                     '- --num_gpus=1: Uses '
#                                     'tf.distribute.OneDeviceStrategy with GPU '
#                                     'as the device.\n'
#                                     '- --num_gpus=2+: Uses '
#                                     'tf.distribute.MirroredStrategy to run '
#                                     'synchronous\n'
#                                     'distributed training across the GPUs.\n'
#                                     '\n'
#                                     'If you wish to run without '
#                                     '`tf.distribute.Strategy`, you can do so '
#                                     'by setting\n'
#                                     '`--distribution_strategy=off`.\n'
#                                     '\n'
#                                     '### Running on Cloud TPUs\n'
#                                     '\n'
#                                     'Note: This model will **not** work with '
#                                     'TPUs on Colab.\n'
#                                     '\n'
#                                     'You can train the ResNet CTL model on '
#                                     'Cloud TPUs using\n'
#                                     '`tf.distribute.TPUStrategy`. If you are '
#                                     'not familiar with Cloud TPUs, it is\n'
#                                     'strongly recommended that you go through '
#                                     'the\n'
#                                     '[quickstart](https://cloud.google.com/tpu/docs/quickstart) '
#                                     'to learn how to\n'
#                                     'create a TPU and GCE VM.\n'
#                                     '\n'
#                                     'To run ResNet model on a TPU, you must '
#                                     'set `--distribution_strategy=tpu` and\n'
#                                     '`--tpu=$TPU_NAME`, where `$TPU_NAME` the '
#                                     'name of your TPU in the Cloud Console.\n'
#                                     'From a GCE VM, you can run the following '
#                                     'command to train ResNet for one epoch\n'
#                                     'on a v2-8 or v3-8 TPU:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_ctl_imagenet_main.py \\\n'
#                                     '  --tpu=$TPU_NAME \\\n'
#                                     '  --model_dir=$MODEL_DIR \\\n'
#                                     '  --data_dir=$DATA_DIR \\\n'
#                                     '  --batch_size=1024 \\\n'
#                                     '  --steps_per_loop=500 \\\n'
#                                     '  --train_epochs=1 \\\n'
#                                     '  --use_synthetic_data=false \\\n'
#                                     '  --dtype=fp32 \\\n'
#                                     '  --enable_eager=true \\\n'
#                                     '  --enable_tensorboard=true \\\n'
#                                     '  --distribution_strategy=tpu \\\n'
#                                     '  --log_steps=50 \\\n'
#                                     '  --single_l2_loss_op=true \\\n'
#                                     '  --use_tf_function=true\n'
#                                     '```\n'
#                                     '\n'
#                                     'To train the ResNet to convergence, run '
#                                     'it for 90 epochs:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python resnet_ctl_imagenet_main.py \\\n'
#                                     '  --tpu=$TPU_NAME \\\n'
#                                     '  --model_dir=$MODEL_DIR \\\n'
#                                     '  --data_dir=$DATA_DIR \\\n'
#                                     '  --batch_size=1024 \\\n'
#                                     '  --steps_per_loop=500 \\\n'
#                                     '  --train_epochs=90 \\\n'
#                                     '  --use_synthetic_data=false \\\n'
#                                     '  --dtype=fp32 \\\n'
#                                     '  --enable_eager=true \\\n'
#                                     '  --enable_tensorboard=true \\\n'
#                                     '  --distribution_strategy=tpu \\\n'
#                                     '  --log_steps=50 \\\n'
#                                     '  --single_l2_loss_op=true \\\n'
#                                     '  --use_tf_function=true\n'
#                                     '```\n'
#                                     '\n'
#                                     'Note: `$MODEL_DIR` and `$DATA_DIR` must '
#                                     'be GCS paths.\n'
#                                     '\n'
#                                     '\n'
#                                     '## MNIST\n'
#                                     '\n'
#                                     'To download the data and run the MNIST '
#                                     'sample model locally for the first time,\n'
#                                     'run one of the following command:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python mnist_main.py \\\n'
#                                     '  --model_dir=$MODEL_DIR \\\n'
#                                     '  --data_dir=$DATA_DIR \\\n'
#                                     '  --train_epochs=10 \\\n'
#                                     '  --distribution_strategy=one_device \\\n'
#                                     '  --num_gpus=$NUM_GPUS \\\n'
#                                     '  --download\n'
#                                     '```\n'
#                                     '\n'
#                                     'To train the model on a Cloud TPU, run '
#                                     'the following command:\n'
#                                     '\n'
#                                     '```bash\n'
#                                     'python mnist_main.py \\\n'
#                                     '  --tpu=$TPU_NAME \\\n'
#                                     '  --model_dir=$MODEL_DIR \\\n'
#                                     '  --data_dir=$DATA_DIR \\\n'
#                                     '  --train_epochs=10 \\\n'
#                                     '  --distribution_strategy=tpu \\\n'
#                                     '  --download\n'
#                                     '```\n'
#                                     '\n'
#                                     'Note: the `--download` flag is only '
#                                     'required the first time you run the '
#                                     'model.\n',
#                           'readme_url': 'https://github.com/tensorflow/models/tree/master/official/vision/image_classification',
#                           'stars': 61091,
#                           'type': 'github',
#                           'url': 'https://github.com/tensorflow/models/tree/master/official/vision/image_classification'}],
#     'name': 'Image Classification',
#     'references': [   {   'title': 'ResNet50 Checkpoints',
#                           'url': 'https://storage.googleapis.com/cloud-tpu-checkpoints/resnet/resnet50.tar.gz'}],
#     'tags': [],
#     'training': {   'datasets': [   {'name': 'MNIST'},
#                                     {'name': 'CIFAR-10'},
#                                     {'name': 'ImageNet'}]},
#     'visibility': {'license': 'Apache License 2.0', 'visibility': 'public'}}

# %%
# This block demonstrates using AIMMX for a particular Python within a repository

metadata = aimmx.repo_parse("https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py")
pprint.pprint(metadata, indent=4)
# Out:
# Extracting AI model metadata from:  keras-team/keras
# {   'authors': [   {   'email': 'francois.chollet@gmail.com',
#                        'github_id': 'fchollet',
#                        'name': 'François Chollet'},
#                    {   'email': 'farizrahman4u@gmail.com',
#                        'github_id': 'farizrahman4u',
#                        'name': 'Fariz Rahman'},
#                    {   'email': 'me@taehoonlee.com',
#                        'github_id': 'taehoonlee',
#                        'name': 'Taehoon Lee'},
#                    {   'email': 'gabrieldemarmiesse@gmail.com',
#                        'github_id': 'gabrieldemarmiesse',
#                        'name': 'Gabriel de Marmiesse'},
#                    {   'email': 'ozabluda@gmail.com',
#                        'github_id': 'ozabluda',
#                        'name': 'Oleg Zabluda'},
#                    {   'email': 'max.pumperla@googlemail.com',
#                        'github_id': 'maxpumperla',
#                        'name': 'Max Pumperla'},
#                    {'github_id': 'EderSantana', 'name': 'Eder Santana'},
#                    {   'email': 'thomas.mccolgan@gmail.com',
#                        'github_id': 'phreeza',
#                        'name': 'Thomas McColgan'},
#                    {'github_id': 'wxs', 'name': 'Xavier Snelgrove'},
#                    {   'github_id': 'Dref360',
#                        'name': 'Frédéric Branchaud-Charron'},
#                    {   'email': 'michael.d.oliver@gmail.com',
#                        'github_id': 'the-moliver',
#                        'name': 'Michael Oliver'},
#                    {'github_id': 'pavithrasv', 'name': 'Pavithra Vijay'},
#                    {   'email': 'k_nzw@klis.tsukuba.ac.jp',
#                        'github_id': 'nzw0301',
#                        'name': 'Kento Nozawa'},
#                    {'github_id': 'matsuyamax', 'name': 'Makoto Matsuyama'},
#                    {'github_id': 'tdhd', 'name': 'Philipp Schmidt'},
#                    {'github_id': 'abhaikollara', 'name': 'Abhai Kollara Dilip'},
#                    {'github_id': 'jfsantos', 'name': 'João Felipe Santos'},
#                    {   'email': 'ATHundt@gmail.com',
#                        'github_id': 'ahundt',
#                        'name': 'Andrew Hundt'},
#                    {'github_id': 'myutwo150', 'name': 'Yu-Yang Huang'},
#                    {   'email': 'ybliang8@gmail.com',
#                        'github_id': 'yanboliang',
#                        'name': 'Yanbo Liang'},
#                    {   'email': 'julien@fhtagn.net',
#                        'github_id': 'julienr',
#                        'name': 'Julien Rebetez'},
#                    {'github_id': 'joosephook', 'name': 'joosephook'},
#                    {   'email': 'fuzzy0427@gmail.com',
#                        'github_id': 'fuzzythecat',
#                        'name': 'fuzzythecat'},
#                    {'github_id': 'gvtulder', 'name': 'Gijs van Tulder'},
#                    {'github_id': 'staticskies', 'name': 'staticskies'},
#                    {   'email': 'tleeuwenburg@gmail.com',
#                        'github_id': 'tleeuwenburg',
#                        'name': 'Tennessee Leeuwenburg'},
#                    {   'email': 'thomas.boquet@hec.ca',
#                        'github_id': 'tboquet',
#                        'name': 'Thomas Boquet'},
#                    {   'email': 'carlthome@gmail.com',
#                        'github_id': 'carlthome',
#                        'name': 'Carl Thomé'},
#                    {   'email': 'lukedeo@ldo.io',
#                        'github_id': 'lukedeo',
#                        'name': 'Luke de Oliveira'},
#                    {'github_id': 'olegsinyavskiy', 'name': 'Oleg Sinyavskiy'},
#                    {'github_id': 'yaringal', 'name': 'yaringal'},
#                    {'github_id': 'jihobak', 'name': 'piper'},
#                    {   'email': 'mail@dahoiv.net',
#                        'github_id': 'Danielhiversen',
#                        'name': 'Daniel Høyer Iversen'},
#                    {'github_id': 'jeammimi', 'name': 'jeammimi'},
#                    {   'email': 'joelthchao@gmail.com',
#                        'github_id': 'joelthchao',
#                        'name': 'Joel'},
#                    {'github_id': 'tristandeleu', 'name': 'Tristan Deleu'},
#                    {   'email': 'pandevirus@gmail.com',
#                        'github_id': 'kemaswill',
#                        'name': 'Junwei Pan'},
#                    {   'email': 'kashif.rasul@gmail.com',
#                        'github_id': 'kashif',
#                        'name': 'Kashif Rasul'},
#                    {'github_id': 'gw0', 'name': 'gw0'},
#                    {   'email': 'joshuarchin@gmail.com',
#                        'github_id': 'Joshua-Chin',
#                        'name': 'Joshua Chin'},
#                    {'github_id': 'keunwoochoi', 'name': 'Keunwoo Choi'},
#                    {   'email': 'souptc@gmail.com',
#                        'github_id': 'souptc',
#                        'name': 'Tang, Cheng'},
#                    {   'email': 'tsukasa@oomo.to',
#                        'github_id': 'henry0312',
#                        'name': 'OMOTO Tsukasa'},
#                    {   'email': 'key.mtrgtring@gmail.com',
#                        'github_id': 'kouml',
#                        'name': 'kouml'},
#                    {'github_id': 'bstriner', 'name': 'Ben'},
#                    {   'email': 'bonadiman.daniele@gmail.com',
#                        'github_id': 'dbonadiman',
#                        'name': 'Daniele Bonadiman'},
#                    {'github_id': 'amitbeka', 'name': 'Amit Beka'},
#                    {'github_id': 'bzamecnik', 'name': 'Bohumír Zámečník'},
#                    {   'email': 'smerity@smerity.com',
#                        'github_id': 'Smerity',
#                        'name': 'Stephen Merity'},
#                    {'github_id': 'datumbox', 'name': 'Vasilis Vryniotis'},
#                    {   'email': 'victor@victorzhong.com',
#                        'github_id': 'vzhong',
#                        'name': 'Victor Zhong'},
#                    {   'email': 'pat.york@nevada.unr.edu',
#                        'github_id': 'patyork',
#                        'name': 'Pat York'},
#                    {   'email': 'Nicholas.Eggert@target.com',
#                        'github_id': 'neggert',
#                        'name': 'Nic Eggert'},
#                    {   'email': 'h.gaiser@fizyr.com',
#                        'github_id': 'hgaiser',
#                        'name': 'Hans Gaiser'},
#                    {   'email': 'jdwittenauer@gmail.com',
#                        'github_id': 'jdwittenauer',
#                        'name': 'John Wittenauer'},
#                    {'github_id': 'mkaze', 'name': 'Masoud Kazemi'},
#                    {   'email': 'raphaelmeudec@gmail.com',
#                        'github_id': 'RaphaelMeudec',
#                        'name': 'Raphael Meudec'},
#                    {   'email': 'kilotaras@gmail.com',
#                        'github_id': 'kilotaras',
#                        'name': 'Taras Boiko'},
#                    {'github_id': 'ghostplant', 'name': 'ghostplant'},
#                    {'github_id': 'kuza55', 'name': 'kuza55'},
#                    {'github_id': 'vkk800', 'name': 'vkk800'},
#                    {'github_id': 'jramapuram', 'name': 'Jason Ramapuram'},
#                    {'github_id': 'cmyr', 'name': 'Colin Rofls'},
#                    {   'github_id': 'angeloskath',
#                        'name': 'Angelos Katharopoulos'},
#                    {'github_id': 'danFromTelAviv', 'name': 'Dan Erez'},
#                    {'github_id': 'kylemcdonald', 'name': 'Kyle McDonald'},
#                    {'github_id': 'matt-gardner', 'name': 'Matt Gardner'},
#                    {'github_id': 'mynameisfiber', 'name': 'Micha Gorelick'},
#                    {   'email': 'stephen@stephenbalaban.com',
#                        'github_id': 'stephenbalaban',
#                        'name': 'Stephen A. Balaban'},
#                    {'github_id': 'berleon', 'name': 'Leon Sixt'},
#                    {   'email': 'dolabot@gmail.com',
#                        'github_id': 'dolaameng',
#                        'name': 'dolaameng'},
#                    {'github_id': 'DingKe', 'name': 'Ke Ding'},
#                    {'github_id': 'ageron', 'name': 'Aurélien Geron'},
#                    {   'email': 'brendan.dwyer@ibm.com',
#                        'github_id': 'bdwyer2',
#                        'name': 'Brendan Dwyer'},
#                    {'github_id': 'braingineer', 'name': 'Brian McMahan'},
#                    {   'email': 'tony.schroeder@gmail.com',
#                        'github_id': 'fredtony',
#                        'name': 'Tony Schroeder'},
#                    {   'email': 'geraslan@broadinstitute.org',
#                        'github_id': 'gokceneraslan',
#                        'name': 'Gökçen Eraslan'},
#                    {'github_id': 'kenterao', 'name': 'kenterao'},
#                    {'github_id': 'mthrok', 'name': 'moto'},
#                    {'github_id': 'rodrigob', 'name': 'Rodrigo Benenson'},
#                    {   'email': 'jeff.zheng.ye@gmail.com',
#                        'github_id': 'jeffzhengye',
#                        'name': 'Jeffery Ye'},
#                    {'github_id': 'masstomato', 'name': 'mass tomato'},
#                    {'github_id': 'icyblade', 'name': 'Yuchao Dai'},
#                    {   'email': 'andhus@kth.se',
#                        'github_id': 'andhus',
#                        'name': 'Anders Huss'},
#                    {   'email': 'dansbecker@gmail.com',
#                        'github_id': 'dansbecker',
#                        'name': 'Dan Becker'},
#                    {'github_id': 'Reddine', 'name': 'Kheir Eddine FARFAR'},
#                    {'github_id': 'nicolewhite', 'name': 'Nicole White'},
#                    {'github_id': 'rilut', 'name': 'Rizky Luthfianto'},
#                    {'github_id': 'caisq', 'name': 'Shanqing Cai'},
#                    {'github_id': 'untom', 'name': 'Thomas Unterthiner'},
#                    {   'email': 'yukoba@gmail.com',
#                        'github_id': 'yukoba',
#                        'name': 'Yu Kobayashi'},
#                    {   'email': 'gh@rushter.com',
#                        'github_id': 'rushter',
#                        'name': 'Artem Golubin'},
#                    {   'email': 'xihuil.silence@gmail.com',
#                        'github_id': 'linxihui',
#                        'name': 'Eric Xihui Lin'},
#                    {   'email': 'graham.annett@gmail.com',
#                        'github_id': 'grahamannett',
#                        'name': 'graham'},
#                    {   'email': 'adam@adamwentz.com',
#                        'github_id': 'awentzonline',
#                        'name': 'Adam Wentz'},
#                    {'github_id': 'basveeling', 'name': 'Bas Veeling'},
#                    {   'email': 'chris.kerr@athion.de',
#                        'github_id': 'frexvahi',
#                        'name': 'Chris'},
#                    {   'email': 'jacopo.notarstefano@gmail.com',
#                        'github_id': 'jacquerie',
#                        'name': 'Jacopo Notarstefano'},
#                    {'github_id': 'whjxnyzh', 'name': 'kai'},
#                    {'github_id': 'viirya', 'name': 'Liang-Chi Hsieh'},
#                    {   'email': 'minkoo.seo@gmail.com',
#                        'github_id': 'minkooseo',
#                        'name': 'Minkoo Seo'},
#                    {'github_id': 'Naruu', 'name': 'Naruu'},
#                    {   'github_id': 'ramananbalakrishnan',
#                        'name': 'Ramanan Balakrishnan'},
#                    {'github_id': 'roatienza', 'name': 'Rowel Atienza'},
#                    {'github_id': 'mezzode', 'name': 'mezzode'},
#                    {'github_id': 'SimonSuster', 'name': 'Simon Šuster'},
#                    {   'email': 'titu1994@gmail.com',
#                        'github_id': 'titu1994',
#                        'name': 'Somshubra Majumdar'},
#                    {   'github_id': 'StefanoCappellini',
#                        'name': 'Stefano Cappellini'},
#                    {   'email': 'me@stephenroller.com',
#                        'github_id': 'stephenroller',
#                        'name': 'Stephen Roller'},
#                    {'github_id': 'SriRangaTarun', 'name': 'Tarun S Paparaju'},
#                    {   'email': 'zhengxin.yong@minerva.kgi.edu',
#                        'github_id': 'yongzx',
#                        'name': 'Yong Zheng Xin'},
#                    {'github_id': 'Yorwba', 'name': 'Yorwba'},
#                    {   'email': 'chezhengping@gmail.com',
#                        'github_id': 'PeterChe1990',
#                        'name': 'Zhengping Che'},
#                    {'github_id': 'alvations', 'name': 'alvations'},
#                    {   'email': 'anayebi@stanford.edu',
#                        'github_id': 'anayebi',
#                        'name': 'Aran Nayebi'},
#                    {   'email': 'nagadomi@gmail.com',
#                        'github_id': 'nagadomi',
#                        'name': 'nagadomi'},
#                    {'github_id': 'cocuh', 'name': 'cocuh '},
#                    {   'email': 'jhessel@cs.cornell.edu',
#                        'github_id': 'jmhessel',
#                        'name': 'Jack Hessel'},
#                    {'github_id': 'wassname', 'name': 'Mike Clark'},
#                    {'github_id': 'ozancaglayan', 'name': 'Ozan Caglayan'},
#                    {'github_id': 'abhinavsagar', 'name': 'Abhinav Sagar'},
#                    {   'email': 'bhat.abishek@gmail.com',
#                        'github_id': 'abishekk92',
#                        'name': 'Abishek Bhat'},
#                    {   'email': 'bharatraghunthan9767@gmail.com',
#                        'github_id': 'Bharat123rox',
#                        'name': 'Bharat Raghunathan'},
#                    {'github_id': 'wb14123', 'name': 'Bin Wang'},
#                    {'github_id': 'dieuwkehupkes', 'name': 'Dieuwke Hupkes'},
#                    {'github_id': 'udibr', 'name': 'Ehud Ben-Reuven'},
#                    {'github_id': 'ericwu09', 'name': 'Eric Wu'},
#                    {'github_id': 'nouiz', 'name': 'Frédéric Bastien'},
#                    {'github_id': 'ziky90', 'name': 'Jan Zikes'},
#                    {'github_id': 'javidcf', 'name': 'Javier Dehesa'},
#                    {   'email': 'ken.chatfield@fmailbox.com',
#                        'github_id': 'kencoken',
#                        'name': 'Ken Chatfield'},
#                    {   'email': 'mbatchkarov@gmail.com',
#                        'github_id': 'mbatchkarov',
#                        'name': 'Miroslav Batchkarov'},
#                    {   'email': 'mohanson@outlook.com',
#                        'github_id': 'mohanson',
#                        'name': 'Mohanson'},
#                    {'github_id': 'pjadzinsky', 'name': 'Pablo Jadzinsky'},
#                    {   'email': 'pasky@ucw.cz',
#                        'github_id': 'pasky',
#                        'name': 'Petr Baudis'},
#                    {'github_id': 'pranv', 'name': 'Pranav Shyam'},
#                    {'github_id': 'rvinas', 'name': 'Ramon Viñas'},
#                    {   'github_id': 'robertomest',
#                        'name': 'Roberto de Moura Estevão Filho'},
#                    {   'email': 'srjoglekar@google.com',
#                        'github_id': 'srjoglekar246',
#                        'name': 'Sachin Joglekar'},
#                    {'github_id': 'sklan', 'name': 'sklan'},
#                    {   'email': 'timbobel@gmail.com',
#                        'github_id': 'TimZaman',
#                        'name': 'Tim Zaman'},
#                    {'github_id': 'vchernobyl', 'name': 'Vitaly Krumins'},
#                    {   'email': 'yang.zhang.ds@gmail.com',
#                        'github_id': 'yang-zhang',
#                        'name': 'Yang Zhang'},
#                    {'github_id': 'nehz', 'name': 'nehz'},
#                    {   'email': 'moyan_work@foxmail.com',
#                        'github_id': 'MoyanZitto',
#                        'name': 'Zhengtao Wang'},
#                    {'github_id': 'charlesollion', 'name': 'charlesollion'},
#                    {'github_id': 'eulerreich', 'name': 'eulerreich'},
#                    {   'email': 'floydwch@gmail.com',
#                        'github_id': 'floydwch',
#                        'name': 'floydwch'},
#                    {'github_id': 'jarfo', 'name': 'Jose Fonollosa'},
#                    {'github_id': 'jorgecarleitao', 'name': 'Jorge Leitao'},
#                    {'github_id': 'knightXun', 'name': 'flyingcat '},
#                    {'github_id': 'smauq', 'name': 'Andrei Cramariuc'},
#                    {   'email': 's.slunkov@gmail.com',
#                        'github_id': 'stas-sl',
#                        'name': 'Stas'},
#                    {'github_id': 't-ae', 'name': 't.ae'},
#                    {'github_id': 'oeway', 'name': 'Wei Ouyang'},
#                    {'github_id': 'bojone', 'name': '苏剑林(Jianlin Su)'},
#                    {   'email': 'ayala.acevedo@gmail.com',
#                        'github_id': 'abnera',
#                        'name': 'Abner Ayala-Acevedo'},
#                    {   'email': 'achalshah20@gmail.com',
#                        'github_id': 'achalshah20',
#                        'name': 'Achal Shah'},
#                    {'github_id': 'alanyee', 'name': 'Alan Yee'},
#                    {'github_id': 'alok', 'name': 'Alok Singh'},
#                    {   'github_id': 'AndreiCostinescu',
#                        'name': 'Andrei Costinescu'},
#                    {   'email': 'anjishnu.kr@gmail.com',
#                        'github_id': 'anjishnu',
#                        'name': 'Anjishnu Kumar'},
#                    {'github_id': 'ArdalanM', 'name': 'Ardalan'},
#                    {'github_id': 'barvinograd', 'name': 'Bar Vinograd'},
#                    {   'email': 'vishal.batchu@students.iiit.ac.in',
#                        'github_id': 'erilyth',
#                        'name': 'Batchu Venkat Vishal'},
#                    {'github_id': 'bbabenko', 'name': 'Boris Babenko'},
#                    {'github_id': 'bottydim', 'name': 'Botty Dimanov'},
#                    {   'email': 'bc@brianchu.com',
#                        'github_id': 'bchu',
#                        'name': 'Brian Chu'},
#                    {'github_id': 'briannemsick', 'name': 'Brian Nemsick'},
#                    {'github_id': 'dstine', 'name': 'Dan Stine'},
#                    {'github_id': 'Dapid', 'name': 'David Menéndez Hurtado'},
#                    {'github_id': 'Denny-Hwang', 'name': 'Denny-Hwang'},
#                    {   'email': 'dgorissen@gmail.com',
#                        'github_id': 'dgorissen',
#                        'name': 'Dirk Gorissen'},
#                    {'github_id': 'lukovkin', 'name': 'Dmitry Lukovkin'},
#                    {   'email': 'Raff.Edward@gmail.com',
#                        'github_id': 'EdwardRaff',
#                        'name': 'EdwardRaff'},
#                    {   'email': 'staticfloat@gmail.com',
#                        'github_id': 'staticfloat',
#                        'name': 'Elliot Saba'},
#                    {'github_id': 'eyalzk', 'name': 'Eyal Zakkay'},
#                    {'github_id': 'faroit', 'name': 'Fabian-Robert Stöter'},
#                    {   'email': 'felixlaumon@gmail.com',
#                        'github_id': 'felixlaumon',
#                        'name': 'Felix Lau'},
#                    {'github_id': 'zo7', 'name': 'flynn'},
#                    {   'github_id': 'ghisvail',
#                        'name': 'Ghislain Antony Vaillant'},
#                    {'github_id': 'arodiss', 'name': 'Gleb Sidora'},
#                    {   'github_id': 'HarikrishnanBalagopal',
#                        'name': 'HarikrishnanBalagopal'},
#                    {   'email': 'hong@topbug.net',
#                        'github_id': 'xuhdev',
#                        'name': 'Hong Xu'},
#                    {'github_id': 'jjallaire', 'name': 'J.J. Allaire'},
#                    {'github_id': 'jrbourbeau', 'name': 'James Bourbeau'},
#                    {   'email': 'jasons89@gmail.com',
#                        'github_id': 'jsaporta',
#                        'name': 'Jason Saporta'},
#                    {'github_id': 'jayanthkoushik', 'name': 'Jayanth Koushik'},
#                    {'github_id': 'linjinjin123', 'name': 'Jinjin Lin'},
#                    {   'email': 'joe.yearsley@kheironmed.com',
#                        'github_id': 'joeyearsley',
#                        'name': 'Joe Yearsley'},
#                    {   'email': 'joshua.d.loyal@gmail.com',
#                        'github_id': 'joshloyal',
#                        'name': 'Joshua Loyal'},
#                    {   'email': 'crowsonkb@gmail.com',
#                        'github_id': 'crowsonkb',
#                        'name': 'Katherine Crowson'},
#                    {'github_id': 'easyas314159', 'name': 'Kevin Loney'},
#                    {'github_id': 'kmader', 'name': 'Kevin Mader'},
#                    {'github_id': 'NickShahML', 'name': 'NK'},
#                    {'github_id': 'Leoyzen', 'name': 'Leoyzen'},
#                    {'github_id': 'lunardog', 'name': 'Leszek'},
#                    {'github_id': 'JustLou', 'name': 'Lou'},
#                    {'github_id': 'lucasdavid', 'name': 'Lucas David'},
#                    {'github_id': 'lukeyeager', 'name': 'Luke Yeager'},
#                    {   'email': 'un.pensiero.vano@gmail.com',
#                        'github_id': 'ynqa',
#                        'name': '¯\\_(ツ)_/¯'},
#                    {'github_id': 'MartinThoma', 'name': 'Martin Thoma'},
#                    {'github_id': 'rollingstone', 'name': 'Marzuk Kamal'},
#                    {   'email': 'michael.dietz@waya.ai',
#                        'github_id': 'mjdietzx',
#                        'name': 'Michael Dietz'},
#                    {   'email': 'contact@tiger-222.fr',
#                        'github_id': 'BoboTiG',
#                        'name': 'Mickaël Schoentgen'},
#                    {   'email': 'moutai10@gmail.com',
#                        'github_id': 'moutai',
#                        'name': 'Moussa Taifi'},
#                    {'github_id': 'N-McA', 'name': 'N-McA'},
#                    {   'email': 'nigeljyng@gmail.com',
#                        'github_id': 'nigeljyng',
#                        'name': 'Nigel Ng'},
#                    {'github_id': 'nisargjhaveri', 'name': 'Nisarg Jhaveri'},
#                    {   'email': 'NITHISH.divakar@gmail.com',
#                        'github_id': 'nithishdivakar',
#                        'name': 'Nithish deva Divakar'},
#                    {'github_id': 'obilaniu', 'name': 'Olexa Bilaniuk'},
#                    {'github_id': 'heytitle', 'name': 'Pattarawat Chormai'},
#                    {'github_id': 'pstjohn', 'name': 'Peter St. John'},
#                    {'github_id': 'piperchester', 'name': 'Piper'},
#                    {'github_id': 'pokey', 'name': 'Pokey Rule'},
#                    {   'email': 'riknijessen@gmail.com',
#                        'github_id': 'gewoonrik',
#                        'name': 'Rik Nijessen'},
#                    {   'email': 'bryant@montevideo.com.uy',
#                        'github_id': 'bryant1410',
#                        'name': 'Santiago Castro'},
#                    {   'email': 'sasankchilamkurthy@gmail.com',
#                        'github_id': 'chsasank',
#                        'name': 'Sasank Chilamkurthy'},
#                    {'github_id': 'woozzu', 'name': 'Seonghyeon Nam'},
#                    {'github_id': 'Sebubu', 'name': 'Severin Bühler'},
#                    {   'email': 'laishaovan@gmail.com',
#                        'github_id': 'Shaofanl',
#                        'name': 'Shaofan Lai'},
#                    {   'email': 'simon@smgt.me',
#                        'github_id': 'smgt',
#                        'name': 'Simon Gate'},
#                    {   'email': 'simonmarkwarren@gmail.com',
#                        'github_id': 'SimonMWarren',
#                        'name': 'Simon Warren'},
#                    {'github_id': 'SnehaNB', 'name': 'SnehaNB'},
#                    {   'email': 'spotlight0xff@gmail.com',
#                        'github_id': 'Spotlight0xff',
#                        'name': 'Spotlight0xff'},
#                    {'github_id': 'StefanoD', 'name': 'Stefano'},
#                    {   'email': 'sumitgt007@gmail.com',
#                        'github_id': 'sumitgouthaman',
#                        'name': 'Sumit Gouthaman'},
#                    {'github_id': 'osh', 'name': "Tim O'Shea"},
#                    {'github_id': 'yhenon', 'name': 'Yann Henon'},
#                    {   'email': 'yxonic@gmail.com',
#                        'github_id': 'yxonic',
#                        'name': 'Yu Yin'},
#                    {   'email': 'yves@dbtune.org',
#                        'github_id': 'moustaki',
#                        'name': 'Yves Raimond'},
#                    {'github_id': 'abrad1212', 'name': 'abrad1212'},
#                    {'github_id': 'antonmbk', 'name': 'antonmbk'},
#                    {'github_id': 'bonlime', 'name': 'bonlime'},
#                    {   'email': 'cclauss@me.com',
#                        'github_id': 'cclauss',
#                        'name': 'Christian Clauss'},
#                    {'github_id': 'drauh', 'name': 'Malo Huard'},
#                    {'github_id': 'ebatuhankaynak', 'name': 'ebatuhankaynak'},
#                    {   'email': 'maiyo.elton@gmail.com',
#                        'github_id': 'eltronix',
#                        'name': 'Elton Maiyo'},
#                    {'github_id': 'flomlo', 'name': 'flomlo'},
#                    {'github_id': 'stanpcf', 'name': 'fpc'},
#                    {   'email': 'swang150@ucsc.edu',
#                        'github_id': 'ipod825',
#                        'name': 'Shih-Ming Wang'},
#                    {'github_id': 'jcuypers', 'name': 'jcuypers'},
#                    {'github_id': 'jpeg729', 'name': 'jpeg729'},
#                    {'github_id': 'leereeves', 'name': 'leereeves'},
#                    {   'email': 'lucas.moura128@gmail.com',
#                        'github_id': 'lucasmoura',
#                        'name': 'lucasmoura'},
#                    {'github_id': 'meberstein', 'name': 'meberstein'},
#                    {'github_id': 'mjacquem1', 'name': 'mjacquem1'},
#                    {'github_id': 'tzachar', 'name': 'tzachar'},
#                    {'github_id': 'omalleyt12', 'name': 'omalleyt12'},
#                    {'github_id': 'stonebig', 'name': 'stonebig'},
#                    {   'email': 'tv.github@beamnet.de',
#                        'github_id': 't-vi',
#                        'name': 'Thomas Viehmann'},
#                    {'github_id': 'tanzhenyu', 'name': 'tanzhenyu'},
#                    {'github_id': 'td2014', 'name': 'td2014'},
#                    {   'email': 'valtron2000+gh@gmail.com',
#                        'github_id': 'valtron',
#                        'name': 'valtron'},
#                    {'github_id': 'luoch', 'name': '罗诚'},
#                    {'github_id': 'chenb67', 'name': 'Chen'},
#                    {'github_id': 'sadreamer', 'name': 'Denis Fedorenko'},
#                    {'github_id': 'heathhenley', 'name': 'Heath Henley'},
#                    {   'email': 'hiroya.chiba@gmail.com',
#                        'github_id': 'hiroyachiba',
#                        'name': 'Hiroya Chiba'},
#                    {   'email': 'cympfh@gmail.com',
#                        'github_id': 'cympfh',
#                        'name': '/c/ympfh'},
#                    {'github_id': '3h4', 'name': '3h4'},
#                    {'github_id': '5ke', 'name': '5ke'},
#                    {   'email': 'shb_6600@qq.com',
#                        'github_id': 'AIshb',
#                        'name': 'Hongbin Shi'},
#                    {'github_id': 'abhipn', 'name': 'Abhijith Nair'},
#                    {   'github_id': 'adamcavendish',
#                        'name': 'Adam Basfop Cavendish'},
#                    {'github_id': 'durana', 'name': 'Adam Durana'},
#                    {   'email': 'adam@adammenges.com',
#                        'github_id': 'adammenges',
#                        'name': 'Adam Menges'},
#                    {   'email': 'chawla.akshay1234@gmail.com',
#                        'github_id': 'akshaychawla',
#                        'name': 'Akshay Chawla'},
#                    {'github_id': 'alito', 'name': 'Alejandro Dubrovsky'},
#                    {   'github_id': 'apbard',
#                        'name': 'Alessandro Pietro Bardelli'},
#                    {   'email': 'alexeftimiades@gmail.com',
#                        'github_id': 'aeftimia',
#                        'name': 'Alex Eftimiades'},
#                    {'github_id': 'krizp', 'name': 'Alex Filiuta'},
#                    {'github_id': 'agalst', 'name': 'Alex Galst'},
#                    {   'email': "alex [dot] rubinsteyn [at] google's friendly "
#                                 'email service',
#                        'github_id': 'iskandr',
#                        'name': 'Alex Rubinsteyn'},
#                    {   'email': 'alexander.sergeev@live.com',
#                        'github_id': 'alsrgv',
#                        'name': 'Alex Sergeev'},
#                    {   'email': 'shishenya@cvisionlab.com',
#                        'github_id': 'Alex1729',
#                        'name': 'Alexander'},
#                    {'github_id': 'Avi2011class', 'name': 'Alexander Ivanov'},
#                    {   'email': 'ameasure@gmail.com',
#                        'github_id': 'ameasure',
#                        'name': 'Alexander Measure'},
#                    {   'github_id': 'alexander-rakhlin',
#                        'name': 'Alexander Rakhlin'},
#                    {'github_id': 'alexkirsz', 'name': 'Alexandre Kirszenberg'},
#                    {   'github_id': 'ASvyatkovskiy',
#                        'name': 'Alexey Svyatkovskiy'},
#                    {'github_id': 'alfasst', 'name': 'Alfas Esty'},
#                    {   'email': 'alfredo.canziani@gmail.com',
#                        'github_id': 'Atcold',
#                        'name': 'Alfredo Canziani'},
#                    {'github_id': 'manashty', 'name': 'Alireza Manashty'},
#                    {'github_id': 'alvarouc', 'name': 'Alvaro Ulloa'},
#                    {'github_id': 'amaotone', 'name': 'Amane Suzuki'},
#                    {'github_id': 'AmirAlavi', 'name': 'Amir Alavi'},
#                    {'github_id': 'hadifar', 'name': 'Amir Hadifar'},
#                    {'github_id': 'basaundi', 'name': 'Ander'},
#                    {'github_id': 'DreSimpelo', 'name': 'Andre Simpelo'},
#                    {'github_id': 'aesuli', 'name': 'Andrea Esuli'},
#                    {   'email': 't3kcit+githubspam@gmail.com',
#                        'github_id': 'amueller',
#                        'name': 'Andreas Mueller'},
#                    {   'email': 'andrew.docherty@data61.csiro.au',
#                        'github_id': 'adocherty',
#                        'name': 'Andrew Docherty'},
#                    {'github_id': 'andrewnaguib', 'name': 'Andrew Naguib'},
#                    {'github_id': 'pavlin99th', 'name': 'Andrew Poliakov'},
#                    {   'email': 'stromnov@gmail.com',
#                        'github_id': 'stromnov',
#                        'name': 'Andrew Stromnov'},
#                    {'github_id': 'melentye', 'name': 'Andrey M'},
#                    {   'email': 'andreyzakharevich@gmail.com',
#                        'github_id': 'andreyz4k',
#                        'name': 'Andrey Zakharevich'},
#                    {'github_id': 'apisarek', 'name': 'Andrzej Pisarek'},
#                    {'github_id': 'andreArtelt', 'name': 'André Artelt'},
#                    {   'github_id': 'Anirudh-Swaminathan',
#                        'name': 'Anirudh Swaminathan'},
#                    {   'email': 'shah.anish07@gmail.com',
#                        'github_id': 'AnishShah',
#                        'name': 'Anish Shah'},
#                    {   'email': 'anner.de.jong@outlook.com',
#                        'github_id': 'Anner-deJong',
#                        'name': 'Anner'},
#                    {'github_id': 'agitter', 'name': 'Anthony Gitter'},
#                    {'github_id': 'splinter89', 'name': 'Anton Cherniavskyi'},
#                    {'github_id': 'arel', 'name': 'Arel Cordero'},
#                    {   'email': 'arokem@gmail.com',
#                        'github_id': 'arokem',
#                        'name': 'Ariel Rokem'},
#                    {'github_id': 'ArnoutDevos', 'name': 'Arnout Devos'},
#                    {'github_id': 'aronj', 'name': 'Aron Janarv'},
#                    {'github_id': 'arpit15', 'name': 'Arpit Agarwal'},
#                    {   'email': 'arthurcburigo@gmail.com',
#                        'github_id': 'acburigo',
#                        'name': 'Arthur Crippa Búrigo'},
#                    {'github_id': 'arundasan91', 'name': 'Arun Das'},
#                    {'github_id': 'al626', 'name': 'Arun Lobo'},
#                    {   'email': 'hello@veniversum.me',
#                        'github_id': 'veniversum',
#                        'name': 'Aw Young Qingzhuo'},
#                    {'github_id': 'BaylorRae', 'name': "Baylor Rae'"},
#                    {   'email': 'ben+github@benmabey.com',
#                        'github_id': 'bmabey',
#                        'name': 'Ben Mabey'},
#                    {'github_id': 'codekansas', 'name': 'Benjamin Bolte'},
#                    {'github_id': 'nebw', 'name': 'Benjamin Wild'},
#                    {'github_id': 'berkatmaca', 'name': 'Berk Atmaca'},
#                    {'github_id': 'BertrandDechoux', 'name': 'Bertrand Dechoux'},
#                    {   'email': 'bhargav.mangipudi@gmail.com',
#                        'github_id': 'bhargav',
#                        'name': 'Bhargav Mangipudi'},
#                    {'github_id': 'bjtho08', 'name': 'Bjarne Thorsted'},
#                    {   'email': 'brettnaul@gmail.com',
#                        'github_id': 'bnaul',
#                        'name': 'Brett Naul'},
#                    {'github_id': 'bryan-lunt', 'name': 'Bryan Lunt'},
#                    {'github_id': 'bbenligiray', 'name': 'Burak Benligiray'},
#                    {'github_id': 'CVxTz', 'name': 'Mansar Youness'},
#                    {'github_id': 'cbentes', 'name': 'Carlos Bentes'},
#                    {   'github_id': 'cadurosar',
#                        'name': 'Carlos Eduardo Rosar Kós Lassance'},
#                    {   'email': 'seriousran@gmail.com',
#                        'github_id': 'seriousran',
#                        'name': 'Chanran Kim'},
#                    {'github_id': 'chasebrignac', 'name': 'chase'},
#                    {'github_id': 'entron', 'name': 'Cheng Guo'},
#                    {'github_id': 'chentaMS', 'name': 'chentaMS'},
#                    {   'email': 'cheukting.ho@gmail.com',
#                        'github_id': 'Cheukting',
#                        'name': 'Cheuk Ting Ho'},
#                    {   'email': 'solesschong@gmail.com',
#                        'github_id': 'SolessChong',
#                        'name': 'Chong Soless'},
#                    {   'email': 'chriscaruso@live.com',
#                        'github_id': 'chcaru',
#                        'name': 'Chris Caruso'},
#                    {   'github_id': 'christian-lanius',
#                        'name': 'Christian Lanius'},
#                    {'github_id': 'ChrisGll', 'name': 'Christophe Gardella'},
#                    {'github_id': 'cengh', 'name': 'Clara Eng'},
#                    {   'email': 'clemens@build2be.com',
#                        'github_id': 'clemens-tolboom',
#                        'name': 'Clemens Tolboom'},
#                    {   'email': 'collindo@gmail.com',
#                        'github_id': 'colllin',
#                        'name': 'Collin Donahue-Oponski'},
#                    {   'email': 'chicong.v@gmail.com',
#                        'github_id': 'vochicong',
#                        'name': 'Cong'},
#                    {   'email': 'corentin.smith@gmail.com',
#                        'github_id': 'cosmith',
#                        'name': 'Corentin Smith'},
#                    {'github_id': 'cgratie', 'name': 'Cristian Gratie'},
#                    {'github_id': 'deltheil', 'name': 'Cédric Deltheil'},
#                    {'github_id': 'dan-nadler', 'name': 'Dan Nadler'},
#                    {'github_id': '23pointsNorth', 'name': 'Daniel Angelov'},
#                    {   'email': 'dancrispell@gmail.com',
#                        'github_id': 'decrispell',
#                        'name': 'Daniel Crispell'},
#                    {'github_id': 'danieljl', 'name': 'Daniel Julius Lasiman'},
#                    {'github_id': 'danielS91', 'name': 'Daniel Seichter'},
#                    {   'email': 'daniele.grattarola@gmail.com',
#                        'github_id': 'danielegrattarola',
#                        'name': 'Daniele Grattarola'},
#                    {   'email': 'me@danieldk.eu',
#                        'github_id': 'danieldk',
#                        'name': 'Daniël de Kok'},
#                    {   'email': 'daniyarttt@gmail.com',
#                        'github_id': 'DaniyarM',
#                        'name': 'DaniyarM'},
#                    {'github_id': 'Dandandan', 'name': 'Daniël Heres'},
#                    {'github_id': 'davechallis', 'name': 'Dave Challis'},
#                    {   'email': 'dave.willmer@gmail.com',
#                        'github_id': 'dwillmer',
#                        'name': 'Dave Willmer'},
#                    {'github_id': 'capybaralet', 'name': 'David Krueger'},
#                    {'github_id': 'davidslac', 'name': 'David Schneider'},
#                    {'github_id': 'dschwertfeger', 'name': 'David Schwertfeger'},
#                    {   'email': 'davidtvs10@gmail.com',
#                        'github_id': 'davidtvs',
#                        'name': 'David Silva'},
#                    {'github_id': 'davidvetrano', 'name': 'David Vetrano'},
#                    {   'email': 'daviddelaiglesiacastro@gmail.com',
#                        'github_id': 'daavoo',
#                        'name': 'David de la Iglesia Castro'},
#                    {   'email': 'hevensun@126.com',
#                        'github_id': 'hevensun',
#                        'name': 'Davy Song'},
#                    {'github_id': 'soulbliss', 'name': 'Deepak Garasangi'},
#                    {'github_id': 'nittanycolonial', 'name': 'Dennis Salguero'},
#                    {   'email': 'dery.ra@gmail.com',
#                        'github_id': 'deryrahman',
#                        'name': 'Dery Rahman Ahaddienata'},
#                    {'github_id': 'dmadeka', 'name': 'Dhruv Madeka'},
#                    {'github_id': 'diogofferreira', 'name': 'Diogo Ferreira'},
#                    {'github_id': 'ducha-aiki', 'name': 'Dmytro Mishkin'},
#                    {'github_id': 'DomHudson', 'name': 'DomHudson'},
#                    {'github_id': 'DominicBreuker', 'name': 'Dominic Breuker'},
#                    {'github_id': 'dmaniry', 'name': 'Dominique Maniry'},
#                    {   'email': 'doug.coleman@gmail.com',
#                        'github_id': 'erg',
#                        'name': 'Doug Coleman'},
#                    {   'email': 'dougal@dougalmatthews.com',
#                        'github_id': 'd0ugal',
#                        'name': 'Dougal Matthews'},
#                    {'github_id': 'durgeshm', 'name': 'Durgesh Mankekar'},
#                    {'github_id': 'edrogers', 'name': 'Ed Rogers'},
#                    {'github_id': 'eliberis', 'name': 'Edgar Liberis'},
#                    {'github_id': 'edsonmedina', 'name': 'Edson Medina'},
#                    {   'email': 'me@eltonviana.com',
#                        'github_id': 'eltonvs',
#                        'name': 'Elton Viana'},
#                    {'github_id': 'emad', 'name': 'Emad El-Haraty'},
#                    {'github_id': 'erfannoury', 'name': 'Erfan Noury'},
#                    {'github_id': 'edlanglois', 'name': 'Eric Langlois'},
#                    {   'email': 'ersmistad@gmail.com',
#                        'github_id': 'smistad',
#                        'name': 'Erik Smistad'},
#                    {   'email': 'evanjhub@gmail.com',
#                        'github_id': 'evhub',
#                        'name': 'Evan Hubinger'},
#                    {'github_id': 'EyeBool', 'name': 'EyeBool'},
#                    {   'email': 'felix.sonntag@outlook.com',
#                        'github_id': 'fsonntag',
#                        'name': 'Felix Sonntag'},
#                    {   'email': 'filiplamparski@gmail.com',
#                        'github_id': 'FLamparski',
#                        'name': 'Filip Wieland'},
#                    {   'email': 'sebastian@wallkoetter.net',
#                        'github_id': 'FirefoxMetzger',
#                        'name': 'Sebastian Wallkötter'},
#                    {'github_id': 'fran-babylon', 'name': 'Fran'},
#                    {'github_id': 'fbrundu', 'name': 'Francesco G. Brundu'},
#                    {   'email': 'fran6co@gmail.com',
#                        'github_id': 'fran6co',
#                        'name': 'Francisco Facioni'},
#                    {   'github_id': 'FuriouslyCurious',
#                        'name': 'Furiously Curious'},
#                    {'github_id': 'gklambauer', 'name': 'G K'},
#                    {'github_id': 'GPhilo', 'name': 'GPhilo'},
#                    {'github_id': 'GabrielBianconi', 'name': 'Gabriel Bianconi'},
#                    {   'email': 'xinsongdu@ufl.edu',
#                        'github_id': 'GalaxyDream',
#                        'name': 'Xinsong Du'},
#                    {   'email': 'gjensen@navexglobal.com',
#                        'github_id': 'GarrisonJ',
#                        'name': 'Garrison Jensen'},
#                    {   'email': 'georg@makeclean.org',
#                        'github_id': 'jgrnt',
#                        'name': 'Georg Göri'},
#                    {   'email': 'georgwiese@gmail.com',
#                        'github_id': 'georgwiese',
#                        'name': 'Georg Wiese'},
#                    {'github_id': 'geohot', 'name': 'George Hotz'},
#                    {'github_id': 'GregFrench', 'name': 'Greg French'},
#                    {'github_id': 'GregorySenay', 'name': 'Gregory'},
#                    {   'email': 'gregory.morse@live.com',
#                        'github_id': 'GregoryMorse',
#                        'name': 'Gregory Morse'},
#                    {'github_id': 'rodgzilla', 'name': 'Grégory Châtel'},
#                    {'github_id': 'lathen', 'name': 'Gunnar Läthén'},
#                    {'github_id': 'haifeng-jin', 'name': 'Haifeng Jin'},
#                    {   'email': 'hijoe320@gmail.com',
#                        'github_id': 'hijoe320',
#                        'name': 'H. Qu'},
#                    {   'email': 'haley.wu.1201@gmail.com',
#                        'github_id': 'HappyStorm',
#                        'name': 'HaleyWu'},
#                    {   'email': 'hotdogee@gmail.com',
#                        'github_id': 'hotdogee',
#                        'name': 'Han Lin'},
#                    {   'email': 'hvivianshaw@gmail.com',
#                        'github_id': 'vivshaw',
#                        'name': 'Hannah Vivian Shaw'},
#                    {'github_id': 'BiggerHao', 'name': 'Hao Cheng'},
#                    {   'email': 'morenoh149@gmail.com',
#                        'github_id': 'morenoh149',
#                        'name': 'Harry Moreno'},
#                    {'github_id': 'HelgeS', 'name': 'HelgeS'},
#                    {'github_id': 'hendriks73', 'name': 'Hendrik Schreiber'},
#                    {   'email': 'guohengkaighk@gmail.com',
#                        'github_id': 'guohengkai',
#                        'name': 'Hengkai Guo'},
#                    {   'email': 'hideaki.kanehara@gmail.com',
#                        'github_id': 'vwrs',
#                        'name': 'Hideaki Kanehara'},
#                    {'github_id': 'hiromichinomata', 'name': 'Hiromichi NOMATA'},
#                    {'github_id': 'hsgkim', 'name': 'Hoeseong Kim'},
#                    {'github_id': 'hhkarimi', 'name': 'Hussain Karimi'},
#                    {   'email': 'hsandsmark@gmail.com',
#                        'github_id': 'hakos',
#                        'name': 'Håkon Sandsmark'},
#                    {'github_id': 'igormq', 'name': 'Igor Macedo Quintanilha'},
#                    {   'email': 'ilayaraja97@gmail.com',
#                        'github_id': 'ilayaraja97',
#                        'name': 'Ilayaraja'},
#                    {   'email': 'ilya.ivanov.se@gmail.com',
#                        'github_id': 'ilivans',
#                        'name': 'Ilya Ivanov'},
#                    {   'email': 'kulikov@cs.nyu.edu',
#                        'github_id': 'uralik',
#                        'name': 'Ilia Kulikov'},
#                    {'github_id': 'Indy9000', 'name': 'Indy M.'},
#                    {   'email': 'jfilippidis@gmail.com',
#                        'github_id': 'johnyf',
#                        'name': 'Ioannis Filippidis'},
#                    {   'email': 'israelg99@gmail.com',
#                        'github_id': 'israelg99',
#                        'name': 'Julian Gilyadov'},
#                    {'github_id': 'yoks', 'name': 'Ivan Anisimov'},
#                    {   'email': 'sosnovikivan@gmail.com',
#                        'github_id': 'ISosnovik',
#                        'name': 'Ivan Sosnovik'},
#                    {'github_id': 'inexxt', 'name': 'Jacek Karwowski'},
#                    {   'email': 'b.jaivarsan2016@vitstudent.ac.in',
#                        'github_id': 'greed2411',
#                        'name': 'Jaivarsan'},
#                    {   'email': 'jake@jakebecker.org',
#                        'github_id': 'JakeBecker',
#                        'name': 'Jake Becker'},
#                    {   'github_id': 'JamesHinshelwood',
#                        'name': 'James Hinshelwood'},
#                    {'github_id': 'jankrepl', 'name': 'Jan'},
#                    {'github_id': 'jstypka', 'name': 'Jan Stypka'},
#                    {'github_id': 'jdoerrie', 'name': 'Jan Wilken Dörrie'},
#                    {'github_id': 'yosinski', 'name': 'Jason Yosinski'}],
#     'definition': {   'code': [   {   'description': 'Deep Learning for humans',
#                                       'frameworks': [   'Keras',
#                                                         'scikit-learn',
#                                                         'scikit-learn',
#                                                         'TensorFlow',
#                                                         'Theano'],
#                                       'language': 'Python',
#                                       'license': 'Other',
#                                       'name': 'keras',
#                                       'owner': 'keras-team',
#                                       'pushed_at': '2020-01-15 08:31:23+00:00',
#                                       'repo_type': 'github',
#                                       'stars': 46427,
#                                       'type': 'repo',
#                                       'url': 'https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py'},
#                                   {   'connection': {   'name': 'github_url',
#                                                         'source': {   'url': 'https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py'}},
#                                       'filetype': 'file',
#                                       'name': 'addition_rnn.py',
#                                       'sha': '4de408fb2054241b17157990b68f795d3c5f6284',
#                                       'size': 7461,
#                                       'type': 'code'}]},
#     'description': 'Deep Learning for humans',
#     'domain': {   'domain_prob': 0.6011710592559883,
#                   'domain_type': 'Natural Language Processing',
#                   'task': 'Machine Translation',
#                   'task_prob': 0.9239258120902478},
#     'extraction': [   {   'frameworks': [   'Keras',
#                                             'scikit-learn',
#                                             'scikit-learn',
#                                             'TensorFlow',
#                                             'Theano'],
#                           'issues': True,
#                           'readme': '\n'
#                                     '# An implementation of sequence to '
#                                     'sequence learning for performing '
#                                     'addition\n'
#                                     '\n'
#                                     'Input: "535+61"\n'
#                                     'Output: "596"\n'
#                                     'Padding is handled by using a repeated '
#                                     'sentinel character (space)\n'
#                                     '\n'
#                                     'Input may optionally be reversed, shown '
#                                     'to increase performance in many tasks '
#                                     'in:\n'
#                                     '"Learning to Execute"\n'
#                                     'http://arxiv.org/abs/1410.4615\n'
#                                     'and\n'
#                                     '"Sequence to Sequence Learning with '
#                                     'Neural Networks"\n'
#                                     'http://papers.nips.cc/paper/5346-sequence-to-sequence-learning-with-neural-networks.pdf\n'
#                                     'Theoretically it introduces shorter term '
#                                     'dependencies between source and target.\n'
#                                     '\n'
#                                     'Two digits reversed:\n'
#                                     '+ One layer LSTM (128 HN), 5k training '
#                                     'examples = 99% train/test accuracy in 55 '
#                                     'epochs\n'
#                                     '\n'
#                                     'Three digits reversed:\n'
#                                     '+ One layer LSTM (128 HN), 50k training '
#                                     'examples = 99% train/test accuracy in 100 '
#                                     'epochs\n'
#                                     '\n'
#                                     'Four digits reversed:\n'
#                                     '+ One layer LSTM (128 HN), 400k training '
#                                     'examples = 99% train/test accuracy in 20 '
#                                     'epochs\n'
#                                     '\n'
#                                     'Five digits reversed:\n'
#                                     '+ One layer LSTM (128 HN), 550k training '
#                                     'examples = 99% train/test accuracy in 30 '
#                                     'epochs\n'
#                                     '\n',
#                           'readme_url': 'https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py',
#                           'stars': 46427,
#                           'type': 'github',
#                           'url': 'https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py'}],
#     'name': 'An implementation of sequence to sequence learning for performing '
#             'addition',
#     'tags': [   'deep-learning',
#                 'tensorflow',
#                 'neural-networks',
#                 'machine-learning',
#                 'data-science',
#                 'python'],
#     'training': {   'datasets': [   {   'connection': {   'name': 'url',
#                                                           'source': {   'url': 'https://github.com/keras-team/keras/blob/master/examples/mnist_dataset_api.py'}},
#                                         'name': 'mnist_dataset_api.py'},
#                                     {'name': 'IMDb'},
#                                     {'name': 'bAbi'},
#                                     {'name': 'Sequential MNIST'}]},
#     'visibility': {'license': 'Other', 'visibility': 'public'}}

# %%
# This block is a simple example of gathering metadata from multiple repositories and saving the results somewhere

repos = ["https://github.com/vadimkantorov/cvpr2014", "https://github.com/tensorflow/models/tree/master/official/vision/image_classification", "https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py"]

import json

for repo in repos:
    metadata = aimmx.repo_parse(repo)
    with open(metadata["name"] + ".json", "w") as f:
        json.dump(metadata, f, indent=4)
# Out:
# Extracting AI model metadata from:  vadimkantorov/fastvideofeat
# Extracting AI model metadata from:  tensorflow/models
# Extracting AI model metadata from:  keras-team/keras
